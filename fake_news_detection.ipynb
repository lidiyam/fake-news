#   inflating: train_articles/150776.txt
#   inflating: train_articles/77864.txt
#   inflating: train_articles/97992.txt
#   inflating: train_articles/110311.txt
#   inflating: train_articles/82098.txt
#   inflating: train_articles/92892.txt
#   inflating: train_articles/60001.txt
#   inflating: train_articles/151524.txt
#   inflating: train_articles/55923.txt
#   inflating: train_articles/92653.txt
#   inflating: train_articles/125727.txt
#   inflating: train_articles/111980.txt
#   inflating: train_articles/54535.txt
#   inflating: train_articles/23264.txt
#   inflating: train_articles/77996.txt
#   inflating: train_articles/94414.txt
#   inflating: train_articles/105154.txt
#   inflating: train_articles/28333.txt
#   inflating: train_articles/81137.txt
#   inflating: train_articles/121353.txt
#   inflating: train_articles/66674.txt
#   inflating: train_articles/38133.txt
#   inflating: train_articles/150238.txt
#   inflating: train_articles/5074.txt
#   inflating: train_articles/135341.txt
#   inflating: train_articles/86290.txt
#   inflating: train_articles/93233.txt
#   inflating: train_articles/55119.txt
#   inflating: train_articles/385.txt
#   inflating: train_articles/143685.txt
#   inflating: train_articles/2949.txt
#   inflating: train_articles/93249.txt
#   inflating: train_articles/59884.txt
#   inflating: train_articles/77832.txt
#   inflating: train_articles/100223.txt
#   inflating: train_articles/15703.txt
#   inflating: train_articles/45137.txt
#   inflating: train_articles/38218.txt
#   inflating: train_articles/63200.txt
#   inflating: train_articles/161022.txt
#   inflating: train_articles/3199.txt
#   inflating: train_articles/75444.txt
#   inflating: train_articles/122153.txt
#   inflating: train_articles/29667.txt
#   inflating: train_articles/83269.txt
#   inflating: train_articles/149805.txt
#   inflating: train_articles/95432.txt
#   inflating: train_articles/85430.txt
#   inflating: train_articles/143350.txt
#   inflating: train_articles/153562.txt
#   inflating: train_articles/153412.txt
#   inflating: train_articles/86399.txt
#   inflating: train_articles/142337.txt
#   inflating: train_articles/105083.txt
#   inflating: train_articles/4146.txt
#   inflating: train_articles/71909.txt
#   inflating: train_articles/127261.txt
#   inflating: train_articles/60978.txt
#   inflating: train_articles/161914.txt
#   inflating: train_articles/82958.txt

# %%
import json
import numpy as np


# load metadata
with open("train.json", 'r') as f:
    metadata = json.load(f)
n_claims = len(metadata)

# %%
import torch
import torch.nn as nn
import numpy as np
import random

# %%
# !pip install bpemb
from bpemb import BPEmb
# Out:
# Requirement already satisfied: bpemb in /usr/local/lib/python3.6/dist-packages (0.3.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (from bpemb) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from bpemb) (2.21.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from bpemb) (0.1.82)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from bpemb) (4.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from bpemb) (1.16.4)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim->bpemb) (1.12.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim->bpemb) (1.3.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim->bpemb) (1.8.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->bpemb) (2019.6.16)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim->bpemb) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim->bpemb) (1.9.189)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim->bpemb) (0.2.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.189 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim->bpemb) (1.12.189)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim->bpemb) (0.9.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.189->boto3->smart-open>=1.2.1->gensim->bpemb) (2.5.3)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.189->boto3->smart-open>=1.2.1->gensim->bpemb) (0.14)

# %%
n_embedding_dims = 50
bpemb_en = BPEmb(lang="en", dim=n_embedding_dims)

def sampleClaim(metadata): 
    id = random.randint(0, len(metadata) - 1)
    claim = metadata[id]["claim"]
    embedding = bpemb_en.embed(claim)
    embedding = np.reshape(embedding,(embedding.shape[0],1,embedding.shape[1]))
    label = metadata[id]["label"]
    label_tensor = torch.tensor([label], dtype=torch.long)
    claim_tensor = torch.tensor(embedding, dtype=torch.float)
    return claim_tensor, label_tensor, claim, label, id
  
  
def sampleClaimAndClaimant(metadata): 
    id = random.randint(0, len(metadata) - 1)
    claim = metadata[id]["claim"] + ' ' + metadata[id]["claimant"]
    embedding = bpemb_en.embed(claim)
    embedding = np.reshape(embedding,(embedding.shape[0],1,embedding.shape[1]))
    label = metadata[id]["label"]
    label_tensor = torch.tensor([label], dtype=torch.long)
    claim_tensor = torch.tensor(embedding, dtype=torch.float)
    return claim_tensor, label_tensor, claim, label, id
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
from torch.autograd import Variable
import math
import copy

class PositionalEncoder(nn.Module):
    def __init__(self, d_model, max_seq_len = 80):
        super().__init__()
        self.d_model = d_model
        
        # create constant 'pe' matrix with values dependant on 
        # pos and i
        pe = torch.zeros(max_seq_len, d_model)
        for pos in range(max_seq_len):
            for i in range(0, d_model, 2):
                pe[pos, i] = math.sin(pos / (10000 ** (i / d_model)))
                pe[pos, i + 1] = math.cos(pos / (10000 ** (i / d_model)))
                
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
 
    
    def forward(self, x):
        # make embeddings relatively larger
        x = x * math.sqrt(self.d_model)
        # add constant to embedding
        seq_len = x.size(1)
        x = x + Variable(self.pe[:,:seq_len], requires_grad=False) #.cuda()
        return x

# %%
import torch.nn.functional as F

def attention(q, k, v, d_k, mask=None, dropout=None):
    
    scores = torch.matmul(q, k.transpose(-2, -1)) /  math.sqrt(d_k)
    if mask is not None:
        mask = mask.unsqueeze(1)
        scores = scores.masked_fill(mask == 0, -1e9)
    
    scores = F.softmax(scores, dim=-1)
    
    if dropout is not None:
        scores = dropout(scores)
        
    output = torch.matmul(scores, v)
    return output

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model, dropout = 0.1):
        super().__init__()
        
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads
        
        self.q_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None):
        
        bs = q.size(0)
        
        # perform linear operation and split into h heads
        
        k = self.k_linear(k).view(bs, -1, self.h, self.d_k)
        q = self.q_linear(q).view(bs, -1, self.h, self.d_k)
        v = self.v_linear(v).view(bs, -1, self.h, self.d_k)
                
        # transpose to get dimensions bs * h * sl * d_model
       
        k = k.transpose(1,2)
        q = q.transpose(1,2)
        v = v.transpose(1,2)
        
        # calculate attention using function we will define next
        scores = attention(q, k, v, self.d_k, mask, self.dropout)
        
        # concatenate heads and put through final linear layer
        concat = scores.transpose(1,2).contiguous().view(bs, -1, self.d_model)
        
        output = self.out(concat)
    
        return output

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=2048, dropout = 0.1):
        super().__init__() 
        # We set d_ff as a default to 2048
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    
    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %%
class Norm(nn.Module):
    def __init__(self, d_model, eps = 1e-6):
        super().__init__()
    
        self.size = d_model
        # create two learnable parameters to calibrate normalisation
        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))
        self.eps = eps
    
    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) \
        / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
        return norm

# %%
# build an encoder layer with one multi-head attention layer and one 
# feed-forward layer
class EncoderLayer(nn.Module):
    def __init__(self, d_model, heads, dropout = 0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.attn = MultiHeadAttention(heads, d_model)
        self.ff = FeedForward(d_model)
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
        
    def forward(self, x, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.ff(x2))
        return x

      
# We can then build a convenient cloning function that can generate multiple layers:
def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, N, heads):
        super().__init__()
        self.N = N
        self.pe = PositionalEncoder(d_model)
        self.layers = get_clones(EncoderLayer(d_model, heads), N)
        self.norm = Norm(d_model)
    
    def forward(self, src, mask):
        x = self.pe(src)
        for i in range(N):
            x = self.layers[i](x, mask)
        return self.norm(x)

# %%
class Transformer(nn.Module):
    def __init__(self, d_model, N, heads):
        super().__init__()
        self.encoder = Encoder(d_model, N, heads)
        
    def forward(self, src, src_mask):
        e_outputs = self.encoder(src, src_mask)
        output = torch.sum(e_outputs, dim=0)
        return output

# %%
# from Q2a
class Classifier(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(Classifier, self).__init__()
        self.hidden_size = hidden_size
        self.h2o = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, hidden):
        hidden = self.h2o(hidden)
        output = self.softmax(hidden)
        return output

# %% [markdown]
# # Training

# %%
d_model = 50   # 200
heads = 2      # 8
N = 6
n_categories = 3
model = Transformer(d_model, N, heads)
classifier = Classifier(d_model, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4

optim = torch.optim.Adam(model.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)

# %%
def train(category_tensor, line_tensor, update=True):
    optim.zero_grad()
    classifierOptimizer.zero_grad()

    hidden = model(line_tensor, None)
    output = classifier(hidden)

    loss = criterion(output, category_tensor)
    if update:
        loss.backward()
        optim.step()
        classifierOptimizer.step()
        
    return output, loss.item()

# %%
import time

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
n_iters = 100000
plot_every = 1000

# Keep track of losses for plotting
current_loss = 0
all_losses = []

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]

train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0

all_train_losses = []
all_train_accuracies = []
all_test_losses = []
all_test_accuracies = []

count = 0
for iter in range(1, n_iters + 1):
    train_line_tensor, train_category_tensor, train_line, train_category, train_id = sampleClaim(train_data)
    train_output, train_loss = train(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_line_tensor, test_category_tensor, test_line, test_category, test_id = sampleClaim(test_data)
    test_output, test_loss = train(test_category_tensor, test_line_tensor, update=False)
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_line, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_line, test_guess_category, test_correct))
        
        all_train_losses.append(train_cumulative_loss / plot_every)
        all_train_accuracies.append(average_train_accuracy)
        all_test_losses.append(test_cumulative_loss / plot_every)
        all_test_accuracies.append(average_test_accuracy)
        
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
# Out:
# Train: 1000  1% (2m 17s) average_accuracy=0.4230 average_loss=7.2244 Al Gore's residence uses considerably more energy than the average American home. / 1 ✓
# Test: 1000  1% (2m 17s) average_accuracy=0.4400 average_loss=5.7218 "The Congressional Budget Office -- supposedly non-partisan -- estimates that in just a few years the average cost to every family of four (from cap and trade) will be $6,800 per year." / 1 ✗ (0)
# Train: 2000  2% (4m 28s) average_accuracy=0.4410 average_loss=4.6178 The Affordable Care Act is "not the law of the land." / 1 ✗ (0)
# Test: 2000  2% (4m 28s) average_accuracy=0.4090 average_loss=6.3342 Refugees are throwing rocks and trying "to kill you." / 1 ✗ (0)
# Train: 3000  3% (6m 42s) average_accuracy=0.4360 average_loss=3.9637 President Trump signed a bill blocking Obama-era background checks that would have made it easier to flag mentally ill potential gun purchasers. / 0 ✗ (1)
# Test: 3000  3% (6m 42s) average_accuracy=0.4310 average_loss=3.2535 President Obama ordered flags be flown at half-staff to mark the death of singer Whitney Houston, but he did not extend that honor to former first lady Nancy Reagan.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									while scrolling through the pages I see a post that says Obama lowered the flag for Whitney Houston but not for Nancy Reagan.
#
# _____________________________________________________________________________
#
# How ironic that our flags were not flown at half mass until DC Finally just did for Nancy Reagan..... But it was done right away for Whitney Houston way to go Obama
#
# _____________________________________________________________________________
#
# You know President Obama's a real douchebag will lower the flag for a crack whore Whitney Houston but not former First Lady Nancy Reagan what a grade a asshole he must be
#
# _____________________________________________________________________________
#
# There's a rumor that Pres. Obama ordered the flag lowered for Whitney Huston but not Nancy Reagan, is this true?																			Collected via Facebook and e-mail, March 2016 / 1 ✗ (0)
# Train: 4000  4% (9m 15s) average_accuracy=0.4820 average_loss=2.3579  "This Video Of A Disabled Toddler Trying To Shake Trump’s Hand And Getting Ignored Will Break Your Heart.”  / 0 ✓
# Test: 4000  4% (9m 15s) average_accuracy=0.4630 average_loss=2.4122 "Breaking: FBI just raided the White House, 6 people thrown out." / 2 ✗ (0)
# Train: 5000  5% (11m 25s) average_accuracy=0.4970 average_loss=1.2516 Kenya removing pockets from police uniforms to ‘fight corruption’ / 1 ✗ (0)
# Test: 5000  5% (11m 25s) average_accuracy=0.5140 average_loss=1.0853 Dr Robert Gallo ‘invented HIV’ to ‘wipe out the African race’ / 1 ✗ (0)
# Train: 6000  6% (13m 35s) average_accuracy=0.5030 average_loss=1.2923 The Philadelphia Eagles responded to a tweet from President Trump congratulating the team on winning the Super Bowl by telling the Commander-in-Chief to go f*ck himself. / 0 ✓
# Test: 6000  6% (13m 35s) average_accuracy=0.5150 average_loss=1.2936 Marijuana and THC "have caused emergency room visits to skyrocket." / 0 ✗ (1)
# Train: 7000  7% (15m 47s) average_accuracy=0.4950 average_loss=1.3005 "Governor Palin is the most popular governor in the country." / 1 ✗ (2)
# Test: 7000  7% (15m 47s) average_accuracy=0.4800 average_loss=1.3297 “Human traffickers and sex traffickers take advantage of the wide-open areas between our ports of entry to smuggle thousands of young girls and women into the United States and to sell them into prostitution and modern-day slavery.” / 1 ✗ (0)
# Train: 8000  8% (18m 1s) average_accuracy=0.4860 average_loss=1.2293 Says Beto O’Rourke "has a criminal record that includes DWI and burglary arrests." / 2 ✓
# Test: 8000  8% (18m 1s) average_accuracy=0.4820 average_loss=1.3881 A Danish woman fertilized her own eggs with the frozen sperm of her deceased father. / 0 ✓
# Train: 9000  9% (20m 12s) average_accuracy=0.4890 average_loss=1.1090 Electronic benefits recipients in Iowa can no longer purchase soda and candy as of 1 October 2017. / 0 ✓
# Test: 9000  9% (20m 12s) average_accuracy=0.5250 average_loss=1.2039 Says Alexandria Ocasio-Cortez said, "We must block Trump from stopping the return of the heroic Alabama mother from ISIS. In many ways she is more of a hero then our veterans. Welcome home sister!" / 0 ✓
# Train: 10000  10% (22m 23s) average_accuracy=0.4970 average_loss=1.2824 "Vern Buchanan. His old business was caught illegally funneling over $60,000 in campaign donations to Buchanan to influence his election." / 1 ✓
# Test: 10000  10% (22m 23s) average_accuracy=0.4930 average_loss=1.5261 The U.S. government has agreed to allow China to exercise “eminent domain” as collateral for American debt. / 1 ✗ (0)
# Train: 11000  11% (24m 35s) average_accuracy=0.4680 average_loss=1.2956 "The vast majority of crime that is gun related is committed by people who illegally are possessing that firearm." / 0 ✗ (1)
# Test: 11000  11% (24m 35s) average_accuracy=0.4980 average_loss=1.2579 "Some even advocate wiping out 401(k)s entirely and replacing them with government-run accounts." / 1 ✓
# Train: 12000  12% (26m 50s) average_accuracy=0.5000 average_loss=1.2497 Levi's jeans' famous "two horse" logo represents a slave's being killed.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									MUST READ!!!!! I'm Done Wearing "Levi Jeans". This was just brought to my attention, Back in slavery days they would "Beat" and "Kill" the strongest Black Man On The Plantation. They would do so in front of his family and every other slaves on the plantation. After He'd been beaten, they would tie two "ROPES" one to each of his "LEGS" and those ropes were tied to "TWO HORSES" they would then proceed to beat the horses making them run in opposite directions. Eventually the horses would rip his legs from his body...... The Logo on "Levi Jeans" shows how this process went. You see the two "Slave" owners whipping the horses and the ropes visibly connected from the horses to the mans legs. It's supposed to be amusing and to show how hard it would be to actually tear a pair of these jeans that's why the words "Quality Clothing" appears over both of the horses. Smh I've been wearing these jeans for years, WELL NOT ANYMORE!
#
# 																			Collected via e-mail, February 2016 / 0 ✓
# Test: 12000  12% (26m 50s) average_accuracy=0.5110 average_loss=1.1270 “Afghan military are suspected of molesting minors. However, a public acknowledgement of this fact would mean a rupture of the U.S. relationship with Kabul. But Washington has invested about $700 billion in the Afghan campaign over the last 15 years and is not ready to lose its investments." / 1 ✗ (0)
# Train: 13000  13% (28m 59s) average_accuracy=0.5180 average_loss=1.0676 "Obamacare is going to increase the divorce rate." / 1 ✗ (0)
# Test: 13000  13% (28m 59s) average_accuracy=0.5280 average_loss=1.0542 "Donald Trump dead from a fatal heart attack!" / 1 ✗ (0)
# Train: 14000  14% (31m 12s) average_accuracy=0.4950 average_loss=1.2163 Conservative groups have spent $5 million "against" Tammy Baldwin -- five times more than against all other Democratic U.S. Senate incumbents up for election in 2018 combined. / 0 ✗ (1)
# Test: 14000  14% (31m 12s) average_accuracy=0.5380 average_loss=1.0180 California’s budget surplus is about "$30 billion" / 1 ✓
# Train: 15000  15% (33m 24s) average_accuracy=0.5030 average_loss=1.0096 "Over 97 percent of the scientific community … believe that humans are contributing to climate change." / 1 ✓
# Test: 15000  15% (33m 24s) average_accuracy=0.5210 average_loss=1.0533 "The Republican Party has the worst reputation in American polling of any political party in history." / 0 ✗ (1)
# Train: 16000  16% (35m 37s) average_accuracy=0.5100 average_loss=1.1832 "It’s estimated that 40 percent of all the guns that are sold in the United States occur with no background records check." / 1 ✓
# Test: 16000  16% (35m 37s) average_accuracy=0.5150 average_loss=1.0687 The U.S. government funded Mitch McConnell's care and rehabilitation when he had polio as a child. / 0 ✓
# Train: 17000  17% (37m 49s) average_accuracy=0.4990 average_loss=1.0748 Says Donald Trump has "bankrupted his companies not once, not twice but four times." / 0 ✗ (1)
# Test: 17000  17% (37m 49s) average_accuracy=0.5180 average_loss=1.0457 A video shows a real dragon that fell from the sky in Tibet. / 0 ✓
# Train: 18000  18% (39m 59s) average_accuracy=0.5210 average_loss=1.1558 Photos of March 3 Kenya helicopter crash that killed Ruto's pilot / 0 ✗ (1)
# Test: 18000  18% (39m 59s) average_accuracy=0.5150 average_loss=1.1190 Says that President Barack Obama said an attack on Syria "was going to be a pinprick." / 0 ✓
# Train: 19000  19% (42m 12s) average_accuracy=0.5270 average_loss=1.1150 "Wisconsin lost more jobs over the past 12 months than any other state." / 0 ✗ (2)
# Test: 19000  19% (42m 12s) average_accuracy=0.5210 average_loss=1.0901 "Farouk is on fire." / 0 ✗ (2)
# Train: 20000  20% (44m 23s) average_accuracy=0.4910 average_loss=1.1212  Claims President Trump “wants to eliminate overtime pay for people.”  / 1 ✗ (0)
# Test: 20000  20% (44m 23s) average_accuracy=0.5130 average_loss=1.1520 Says Hillary Clinton won "health care for 8 million children." / 1 ✓
# Train: 21000  21% (46m 31s) average_accuracy=0.5430 average_loss=0.9732 The White House was built using slave labor.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Michelle Obama claims that White House was constructed with slave labor. How many slaves were actually used. The other source I found said there were only five and they were all carpenters.																			Collected via e-mail, July 2016 / 0 ✗ (1)
# Test: 21000  21% (46m 31s) average_accuracy=0.5600 average_loss=0.9460 "I didn’t support Sonia Sotomayor." / 1 ✗ (0)
# Train: 22000  22% (48m 42s) average_accuracy=0.5200 average_loss=1.0130 Members of Congress continue to get paid but military personnel do not during a U.S. government shutdown. / 1 ✗ (2)
# Test: 22000  22% (48m 42s) average_accuracy=0.5270 average_loss=1.0239 “We do have a Trade Deficit with Canada, as we do with almost all countries" / 1 ✗ (0)
# Train: 23000  23% (50m 51s) average_accuracy=0.5200 average_loss=0.9728 "Before Congress, (Tom) Cotton got paid handsomely working for insurance companies and corporate interests." / 0 ✓
# Test: 23000  23% (50m 51s) average_accuracy=0.5440 average_loss=1.0046 "Myrtle Beach man who shot at Hurricane Florence dies after bullet ricochets." ​ / 0 ✓
# Train: 24000  24% (53m 5s) average_accuracy=0.5850 average_loss=0.9620 "One man opposed a flawed strategy in Iraq. One man had the courage to call for change. One man didn't play politics with the truth." / 0 ✗ (2)
# Test: 24000  24% (53m 5s) average_accuracy=0.5310 average_loss=1.0077 Hillary Clinton was arrested by the FBI on 1 April 2016. / 0 ✓
# Train: 25000  25% (55m 18s) average_accuracy=0.5320 average_loss=1.1403 Venomous 'two-striped telamonia' spiders are lurking beneath toilet seats in public restrooms. / 0 ✓
# Test: 25000  25% (55m 18s) average_accuracy=0.5390 average_loss=1.1396 "When President Obama was running for re-election … Senator Sanders was trying to find someone to primary him." / 1 ✓
# Train: 26000  26% (57m 32s) average_accuracy=0.5020 average_loss=1.1347 “Canada’s unemployment rate is at its lowest level since the 1970s.” / 1 ✗ (2)
# Test: 26000  26% (57m 32s) average_accuracy=0.5240 average_loss=1.0017 The world's most-pierced person, Gerard Rogers, was killed while passing through a metal detector at LAX airport. / 0 ✓
# Train: 27000  27% (59m 43s) average_accuracy=0.5350 average_loss=1.0562 "Everything that the armed forces of Russia, and not only the armed forces of Russia, is doing is the jewelry work of a superb surgeon with a laser scalpel. With such work, with the fact that the targets are illuminated, determined and reconnoitered to the precision of a meter, there can be no serious consequences related to civilians." / 0 ✗ (1)
# Test: 27000  27% (59m 43s) average_accuracy=0.5340 average_loss=1.0855 "Your [Obamacare] health insurance is going up … 68 percent, 59 percent, 71 percent.” / 1 ✗ (0)
# Train: 28000  28% (61m 58s) average_accuracy=0.5610 average_loss=1.0523 "Charlie Crist was the only prominent Republican in the country to campaign with Barack Obama before the stimulus passed, on behalf of the stimulus." / 0 ✗ (1)
# Test: 28000  28% (61m 58s) average_accuracy=0.5160 average_loss=1.0076 A video shows a surfer being towed by a great white shark.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via Facebook, January 2016 / 0 ✓
# Train: 29000  28% (64m 10s) average_accuracy=0.5100 average_loss=1.0437 Chlorpyrifos, an insecticide with alleged origins in Nazi Germany, was set to be banned by the EPA over health and environmental safety concerns; but President Trump reversed this decision after Dow Chemicals, a manufacturer of the chemical, donated one million dollars to his inauguration fund. / 1 ✓
# Test: 29000  28% (64m 10s) average_accuracy=0.5310 average_loss=0.9835 Democratic National Committee staffer Seth Rich "apparently was assassinated at 4 in the morning, having given WikiLeaks something like 53,000 emails and 17,000 attachments. ... It turns out, it wasn’t the Russians." / 0 ✓
# Train: 30000  30% (66m 20s) average_accuracy=0.5250 average_loss=1.0160 The immigration visa lottery "randomly hands out green cards without any regard for skill, merit, or the safety of American people." / 0 ✓
# Test: 30000  30% (66m 20s) average_accuracy=0.5250 average_loss=1.0368 "Governor Evers, AG Josh Kaul, and Speaker Robin Vos are demanding ‘Red Flag Gun Seizures’ for Wisconsin, which would allow gun seizures with "no proof, arrest, indictment, conviction or due process at all!" / 0 ✗ (1)
# Train: 31000  31% (68m 36s) average_accuracy=0.5190 average_loss=1.0316 On immigration reform, Marco Rubio "all along has been saying, 'We have to have border security first' " and then "he gets on Spanish TV, he ends up saying, 'No, no. That will never get in the way.' " / 0 ✗ (1)
# Test: 31000  31% (68m 36s) average_accuracy=0.5030 average_loss=1.1181 "(Koch Industries) is among the worst in toxic air pollution in the entire United States ... and churns out more climate-changing greenhouse gases than oil giants Chevron, Shell and Valero." / 1 ✓
# Train: 32000  32% (70m 47s) average_accuracy=0.5370 average_loss=0.9622 "We are the nation that built the Golden Gate Bridge in four years and the Hoover Dam in five. Now, it takes as much as a decade just to plan a major permit or a major infrastructure or anything even remotely major in our country, and that’s ridiculous and it’s going to change.” / 1 ✓
# Test: 32000  32% (70m 47s) average_accuracy=0.5170 average_loss=1.0148 Says Donna Brazile is a "criminal." / 0 ✓
# Train: 33000  33% (72m 57s) average_accuracy=0.5310 average_loss=0.9825 Under a new law regulating abortions, "Even if you're raped, if you don't report it in the first 30 days, the Republicans will force you to have an ultrasound." / 0 ✗ (1)
# Test: 33000  33% (72m 57s) average_accuracy=0.5270 average_loss=1.0322 Billionaire Steve Gouves delivered an inspirational speech on his death bed. / 0 ✓
# Train: 34000  34% (75m 8s) average_accuracy=0.5410 average_loss=1.0669 Says he didn't support the lawsuit to repeal the Affordable Care Act. / 0 ✗ (1)
# Test: 34000  34% (75m 8s) average_accuracy=0.5240 average_loss=1.1687 A white strawberry that tastes like pineapple is available in certain markets.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									https://twitter.com/UberFacts/status/707397251606380544																			Collected via Twitter, March 2016 / 0 ✗ (2)
# Train: 35000  35% (77m 19s) average_accuracy=0.5030 average_loss=1.1267  "We had arrested 17,000 criminals at the southern border so far — well, actually, just last year."  / 1 ✗ (0)
# Test: 35000  35% (77m 19s) average_accuracy=0.4810 average_loss=1.0858 "One would have to go back more than a century to find a scenario where a president’s nominee for the Supreme Court was confirmed by the opposition party in the Senate when the vacancy occurred during an election year." / 1 ✗ (2)
# Train: 36000  36% (79m 30s) average_accuracy=0.5130 average_loss=1.0022 Despite keeping distance from national media interviewers, "I did local press all along, the last three months." / 0 ✗ (1)
# Test: 36000  36% (79m 30s) average_accuracy=0.5760 average_loss=0.9585  "Trump Signed His Latest Executive Order And It Will Effectively Eliminate Mass Amounts Of Democrat Voters."  / 1 ✗ (0)
# Train: 37000  37% (81m 41s) average_accuracy=0.5350 average_loss=0.9585 An audio tape captures VP candidate Tim Kaine yelling at his mistress.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Is there any credibility to a Facebook of TIM KAINE (HILLARY'S VP) MISTRESS EXPOSED. LISTEN TO THIS TAPE AS KAINE GOES CRAZY.																			Collected via e-mail, October 2016 / 1 ✗ (0)
# Test: 37000  37% (81m 41s) average_accuracy=0.5250 average_loss=0.9692 A recent spending bill had at least "$1.6 billion in there ... for schools to give them an opportunity to secure them." / 1 ✓
# Train: 38000  38% (83m 50s) average_accuracy=0.5400 average_loss=0.9580 I "helped pass what, if enacted, would be the largest tax cut in Texas history through the State Senate." / 1 ✓
# Test: 38000  38% (83m 50s) average_accuracy=0.5140 average_loss=0.9631 Justin Timberlake said that “The whole concept of mandatory vaccination schedules is un-American.” / 1 ✗ (0)
# Train: 39000  39% (86m 2s) average_accuracy=0.5560 average_loss=1.0326 Fundamental changes made to the language describing the Wisconsin Idea in the University of Wisconsin System's mission statement were the result of a "drafting error." / 1 ✗ (0)
# Test: 39000  39% (86m 2s) average_accuracy=0.5530 average_loss=1.0367 "Guns have murdered more Americans here at home in recent years than have died on the battlefields of Iraq and Afghanistan." / 1 ✓
# Train: 40000  40% (88m 10s) average_accuracy=0.5480 average_loss=0.9968 Donald Trump said that he believes that the Earth is flat. / 0 ✓
# Test: 40000  40% (88m 10s) average_accuracy=0.5550 average_loss=0.9307  “NASA ADMITS To Spraying Americans With Lithium & Other Chemicals”  / 0 ✓
# Train: 41000  41% (90m 19s) average_accuracy=0.5420 average_loss=0.9976 In an interview with Fox News in September 2018, Madonna said she regretted not voting for Donald Trump in 2016 and would support him in 2020. / 0 ✓
# Test: 41000  41% (90m 19s) average_accuracy=0.5140 average_loss=0.9935  Credits his administration for what he said are “record … college enrollment rates.”  / 1 ✗ (0)
# Train: 42000  42% (92m 32s) average_accuracy=0.5750 average_loss=0.9607 Authorities in Mexico have seized a massive shipment of cocaine headed towards a U.S. government facility. / 1 ✗ (0)
# Test: 42000  42% (92m 32s) average_accuracy=0.5950 average_loss=0.9383 Mandalay Bay security guard Jesus Campos was an "accomplice" to Las Vegas Strip mass shooter Stephen Paddock. / 0 ✓
# Train: 43000  43% (94m 47s) average_accuracy=0.5320 average_loss=1.0589 The United States has “dropped off” a list of the 20 most democratic countries in the world. / 1 ✗ (2)
# Test: 43000  43% (94m 47s) average_accuracy=0.5460 average_loss=0.9575 Says Hillary Clinton "wants to bring in thousands of refugees to America from all around the world without any kind of security screening." / 0 ✓
# Train: 44000  44% (96m 57s) average_accuracy=0.5880 average_loss=0.9102 Wisconsin state and local government workers pay "$500, $600 or in some cases, $1,000" per year in union dues. / 1 ✓
# Test: 44000  44% (96m 57s) average_accuracy=0.5620 average_loss=0.9330 Was the CNN Device Not Delivered? / 0 ✓
# Train: 45000  45% (99m 9s) average_accuracy=0.5310 average_loss=0.9998  The Republican tax plan will be the largest tax cut in U.S. history.  / 1 ✗ (0)
# Test: 45000  45% (99m 9s) average_accuracy=0.5250 average_loss=0.9847 Says Andrew Gillum "wants to abolish ICE and doesn't believe in doing any type of immigration enforcement." / 0 ✗ (1)
# Train: 46000  46% (101m 22s) average_accuracy=0.5260 average_loss=1.0009 Barack Obama was the only U.S. president not to lay a wreath at Arlington National Cemetery on Memorial Day. / 0 ✓
# Test: 46000  46% (101m 22s) average_accuracy=0.5210 average_loss=0.9788 A taxi driver in Nigeria (or Zambia, or New York City, among other places) is using his cab to pick up victims. / 2 ✗ (0)
# Train: 47000  47% (103m 35s) average_accuracy=0.5420 average_loss=0.9865 "We were able to provide $428 million worth of property tax relief." / 1 ✓
# Test: 47000  47% (103m 35s) average_accuracy=0.5260 average_loss=1.0104 "A college loan is the only loan in the United States that you cannot refinance when interest rates go down." / 1 ✓
# Train: 48000  48% (105m 49s) average_accuracy=0.5400 average_loss=0.9640 "Kushner And Wife Ivanka Trump Were Tossed Out Of The White House — And Donald Is Cutting Them Out Of His Will!" / 0 ✓
# Test: 48000  48% (105m 49s) average_accuracy=0.5270 average_loss=1.0333 In January 2018, Walmart announced a plan to close 250 Sam's Club warehouses, leaving 100,000 workers jobless. / 1 ✓
# Train: 49000  49% (108m 2s) average_accuracy=0.5420 average_loss=1.1056 A photograph shows the mouth of an adult suffering from hyperdontia. / 0 ✓
# Test: 49000  49% (108m 2s) average_accuracy=0.5040 average_loss=1.0356 Says President Barack Obama revealed in his State of the Union address that he "now is against earmarks." / 0 ✗ (1)
# Train: 50000  50% (110m 23s) average_accuracy=0.4970 average_loss=1.0204 The stimulus bill includes "$300,000 for a sculpture garden in Miami." / 0 ✓
# Test: 50000  50% (110m 23s) average_accuracy=0.5190 average_loss=1.0272 An image shows "smart dust"  miniaturized RFID technology developed by Hitachi. / 0 ✗ (2)
# Train: 51000  51% (113m 12s) average_accuracy=0.4940 average_loss=1.3578 An image shows a pumpkin spice bologna product from Oscar Mayer. / 1 ✗ (0)
# Test: 51000  51% (113m 12s) average_accuracy=0.4590 average_loss=1.2085 Wrestler Hulk Hogan has passed away after being shot in the head. / 1 ✗ (0)
# Train: 52000  52% (115m 49s) average_accuracy=0.4980 average_loss=1.1027 “To all the self-righteous defenders of 'freedom of speech' who oh-so-ardently proclaimed that FARA registration places no restrictions whatsoever on RT's journalistic work in the US: Withdrawal of Congressional credentials speaks much louder than empty platitudes. And to borrow from Orwell, all ‘foreign agents‘ are equal, but looks like only RT is denied congressional accreditation on the basis of FARA status, while the likes of NHK and China Daily carry on business as usual, and U.S. officials continue to claim that the forced FARA registration for RT America's operating company isn't at all discriminatory.” / 0 ✗ (1)
# Test: 52000  52% (115m 49s) average_accuracy=0.5020 average_loss=1.0262 "The president said he’s going to bring in 250,000 (Syrian and Iraqi) refugees into this country." / 0 ✓
# Train: 53000  53% (118m 8s) average_accuracy=0.5150 average_loss=1.0439 Michelle Obama Said ‘White Folks Are What’s Wrong With America' / 0 ✓
# Test: 53000  53% (118m 8s) average_accuracy=0.4940 average_loss=1.0515 "Less than four cents of every health care dollar is spent on prevention and public health." / 1 ✗ (2)
# Train: 54000  54% (120m 39s) average_accuracy=0.5350 average_loss=0.9982 Denzel Washington criticized Meryl Streep for making a political speech during the 2017 Golden Globes award ceremony. / 0 ✗ (1)
# Test: 54000  54% (120m 39s) average_accuracy=0.5230 average_loss=1.0585 President Trump did not recite the Apostles' Creed as other attendees did during George H.W. Bush's funeral. / 1 ✗ (2)
# Train: 55000  55% (123m 2s) average_accuracy=0.5080 average_loss=0.9932 “We at the Clinton Foundation spend 90 percent — 90 percent of all the money that is donated on behalf of programs of people around the world and in our own country.” / 1 ✗ (2)
# Test: 55000  55% (123m 2s) average_accuracy=0.5490 average_loss=0.9451 Article by orthopedic surgeon Dr. Dave Janda criticizes the ObamaCare Plan as “fascist.” / 0 ✗ (1)
# Train: 56000  56% (125m 19s) average_accuracy=0.4980 average_loss=1.0326 A photographer used sixteen cameras and waited 62 days to capture an image of the full moon above a sunset. / 0 ✓
# Test: 56000  56% (125m 19s) average_accuracy=0.5220 average_loss=1.1358 A woman seeking to bring her peacock along on a flight as an emotional support animal was denied permission to do so by United Airlines. / 0 ✗ (2)
# Train: 57000  56% (127m 42s) average_accuracy=0.5280 average_loss=0.9870 A Virginia lawmaker proposed a bill that mandates on-site physical examinations of children's genitals to determine which gendered bathroom they're authorized to use.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									So I was reading this article and I know there is a lot of transphobic stuff going around but this seemed a little ridiculous. The article states that the VA GOP is pushing to get a "anatomically correct sex" bathroom use. Basically they want to pass a bill that requires children to have their genitals checked before using a bathroom. Sounds a little far fetched.
#
# VA Del. Mark Cole, legislator most likely to be profiled as child molester, files bill to check children's genitals https://t.co/sGIyuP9by1
# — StochasticallyCute (@EmmaCaterine) January 13, 2016
#
#
# #GOP Mark Cole wants to examine kids genitals? Is that correct? https://t.co/I1swzJYfdC — badwolf303 (@badwolf303) January 12, 2016
#
# 																			Collected via e-mail and Twitter, January 2015 / 1 ✓
# Test: 57000  56% (127m 42s) average_accuracy=0.4960 average_loss=0.9947 Say water fluoridation started in Nazi Germany ghettos and death camps to pacify the Jews. / 1 ✗ (0)
# Train: 58000  57% (130m 9s) average_accuracy=0.5380 average_loss=0.9854 "NASA will pay you $100,000 to stay in bed for 60 days!" / 0 ✓
# Test: 58000  57% (130m 9s) average_accuracy=0.5460 average_loss=0.9622 Says President Barack Obama "himself has granted waivers allowing into the United States refugees who provided material support to terrorists." / 0 ✗ (1)
# Train: 59000  59% (132m 45s) average_accuracy=0.4990 average_loss=1.0606 KFC in Dearborn uses separate lines for men and women, a menu written in Arabic, and abides by Shariah Law. / 0 ✓
# Test: 59000  59% (132m 45s) average_accuracy=0.5050 average_loss=0.9907 A young Marine was discharged after footage of his involvement in a racially charged altercation at a Donald Trump rally surfaced.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Was a young Joseph Pryor rejected from the US Marines advanced enlistment list because of assaulting a young African American woman who was protesting at a Donald Trump rally recently?
#
# Joseph Pryor who proudly assaulted a black woman at Donald Trump's rally is now discharged by the US Marine Corps. pic.twitter.com/HfaemOVSEz
# — D (@Delo_Taylor) March 4, 2016
# Can you verify this, it just doesn't "smell" right.
#
# BREAKING: Marines discharge soldier over his role in harassment & assault of young woman at Donald Trump rally.https://t.co/M8YWw1Chy8 — Shaun King (@ShaunKing) March 3, 2016
#
#
#
# 																			Collected via e-mail, Twitter, and Internet, March 2016 / 0 ✗ (1)
# Train: 60000  60% (135m 14s) average_accuracy=0.5280 average_loss=0.9912 "Governor Scott Cut Taxes 40 Times For Florida Families" / 1 ✓
# Test: 60000  60% (135m 14s) average_accuracy=0.5310 average_loss=0.9516 The restaurant review website Zomato suffered an attack that compromised 17 million users' data / 0 ✗ (2)
# Train: 61000  61% (137m 33s) average_accuracy=0.5380 average_loss=0.9585 "Tennessee GOP twitter taken down after tweet exposing Pelosi involved in pedophilia." / 0 ✓
# Test: 61000  61% (137m 33s) average_accuracy=0.5410 average_loss=0.9478 Former FBI agent Peter Strzok issued a tweet calling President Trump a "dictator," a "Russian asset," and an "unhinged madman." / 0 ✓
# Train: 62000  62% (139m 54s) average_accuracy=0.5430 average_loss=0.9578 "In New Jersey, Gov. Christie vetoed legislation to extend early voting." / 0 ✗ (1)
# Test: 62000  62% (139m 54s) average_accuracy=0.5320 average_loss=0.9276 Donald Trump has "described Hillary Clinton as one of the best secretaries of state in history." / 0 ✗ (1)
# Train: 63000  63% (142m 19s) average_accuracy=0.5300 average_loss=0.9895 "California is home to the largest death row population in the Western Hemisphere." / 0 ✗ (2)
# Test: 63000  63% (142m 19s) average_accuracy=0.5190 average_loss=0.9735 A homeowner shot and killed a teenaged boy trespassing during a round of Pokemon Go.
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# People please...these things are created to steal, kill & destroy....your life, Your relationships, your mind.... https://t.co/6ZMBAnBVYl
# — Janie Andrews (@janie_andrews) July 13, 2016
# 																			Collected via Twitter, July 2016 / 0 ✓
# Train: 64000  64% (145m 12s) average_accuracy=0.4730 average_loss=1.1220 Says Catherine Cortez Masto "was happy to line her own pockets with taxpayer dollars when state employees were slammed with frozen salaries." / 0 ✗ (1)
# Test: 64000  64% (145m 12s) average_accuracy=0.4730 average_loss=1.1070 Says each of the past three years "has been the hottest on record." / 0 ✗ (2)
# Train: 65000  65% (148m 6s) average_accuracy=0.5050 average_loss=1.0656  “In the first two job reports since I took the oath of office, we’ve already added nearly half a million new jobs.”  / 1 ✗ (0)
# Test: 65000  65% (148m 6s) average_accuracy=0.4980 average_loss=1.0263 Says Alexandria Ocasio-Cortez said, "We must block Trump from stopping the return of the heroic Alabama mother from ISIS. In many ways she is more of a hero then our veterans. Welcome home sister!" / 1 ✗ (0)
# Train: 66000  66% (150m 57s) average_accuracy=0.5400 average_loss=0.9744 "Corporate entities are paying a lot less taxes this year than they have in the past. Part of that is from a loophole in a bill that was passed in 2015." / 1 ✓
# Test: 66000  66% (150m 57s) average_accuracy=0.5200 average_loss=0.9609 "Fully half the people — our research is showing half the people — in (California) want to leave." / 1 ✓
# Train: 67000  67% (153m 34s) average_accuracy=0.5300 average_loss=0.9711 In one year, the United Nations "did 24 resolutions and 20 of them were against Israel." / 1 ✗ (0)
# Test: 67000  67% (153m 34s) average_accuracy=0.5270 average_loss=0.9491 President Obama apologized for dropping bombs on Japan at the end of World War II.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Did President Obama apologized to Japan for dropping the atomic bomb?																			Collected via e-mail, May 2016 / 1 ✗ (0)
# Train: 68000  68% (156m 30s) average_accuracy=0.4940 average_loss=1.0878 “Everything was done to ensure that our guys, and in their person the entire Caucasus, were humiliated and trampled in the dirt. The result speaks for itself – look at the monstrously disproportionate punishment imposed on our fighters and that [imposed on] the swaggering Irish provocateur Conor McGregor.” / 0 ✗ (1)
# Test: 68000  68% (156m 30s) average_accuracy=0.4890 average_loss=1.0903 Says Texas Department of Public Safety numbers show that 1.6 percent of crime is committed by unauthorized immigrants. / 1 ✓
# Train: 69000  69% (159m 30s) average_accuracy=0.5390 average_loss=1.0177  Claims Mark Zandi, the chief economist at Moody’s Analytics, is "not a Democrat."  / 0 ✓
# Test: 69000  69% (159m 30s) average_accuracy=0.5370 average_loss=1.1269 “We’ve lifted the restrictions on American energy, including shale, oil, natural gas and clean, beautiful coal, of which we have 1,000 years of supply.” / 1 ✗ (0)
# Train: 70000  70% (162m 32s) average_accuracy=0.5400 average_loss=1.0057 The death penalty "is a deterrent that does affect and impact people." / 0 ✗ (1)
# Test: 70000  70% (162m 32s) average_accuracy=0.4980 average_loss=1.0053  Facebook posts claim that Martin Luther King Jr. was a Republican.  / 0 ✓
# Train: 71000  71% (165m 25s) average_accuracy=0.4980 average_loss=1.0017 “‘Design and construction of facilities for military operations training in urban terrain’ – the Americans are starting to train Moldovan saboteurs and special forces in the event of new armed conflict with Transdniester.” / 1 ✗ (0)
# Test: 71000  71% (165m 25s) average_accuracy=0.5620 average_loss=0.9727 A few drops of Visine brand eye drops taken internally will induce uncontrollable diarrhea. / 1 ✗ (0)
# Train: 72000  72% (168m 15s) average_accuracy=0.5350 average_loss=1.0205 "A number of Democrats running for governor want to cut the prison population by 50%" and "that would require the release of thousands of violent felons." / 1 ✓
# Test: 72000  72% (168m 15s) average_accuracy=0.5280 average_loss=0.9815 Says Ted Cruz’s wife Heidi "will be the very first pro-life first lady." / 0 ✗ (1)
# Train: 73000  73% (170m 57s) average_accuracy=0.5510 average_loss=0.9666  George Soros is paying Central Americans to immigrate to the U.S.  / 0 ✓
# Test: 73000  73% (170m 57s) average_accuracy=0.5230 average_loss=0.9831 Despite an agreement with President-elect Donald Trump to keep 1,000 manufacturing jobs in the U.S., Carrier Corporation says it will still relocate hundreds of jobs to Mexico.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Is it true that the actual number of factory jobs saved by Trump is far less than the 1,000 jobs promised? That in fact, the information given to the public was misleading and close to 1,000 jobs will eventually be lost? Didn't Carrier employees receive a letter, after the Trump visit, explaining the company intent to carry through with the re-location of jobs to Mexico?																			Collected via e-mail, December 2016 / 0 ✗ (2)
# Train: 74000  74% (173m 29s) average_accuracy=0.5440 average_loss=1.0140 A woman was arrested for masturbating with a Happy Meal toy inside a McDonald's play area ball pit.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Woman arrested for masturbating with happy meal toy in McDonald's Play Place																			Collected via e-mail, May 2016 / 0 ✓
# Test: 74000  74% (173m 29s) average_accuracy=0.5210 average_loss=1.0633 A video documents that the shootings at Sandy Hook Elementary School were a staged hoax. / 0 ✓
# Train: 75000  75% (176m 10s) average_accuracy=0.5490 average_loss=0.9447 A man named Shane Patrick Boyle died shortly after starting a GoFundMe fundraiser for insulin. / 0 ✗ (2)
# Test: 75000  75% (176m 10s) average_accuracy=0.5560 average_loss=0.9460 Says Syrian refugees are not being vetted, and "the FBI is not even being told where they are." / 0 ✗ (1)
# Train: 76000  76% (178m 44s) average_accuracy=0.5250 average_loss=1.0476 When New York Gov. Eliot Spitzer wanted to "provide driver’s licenses to those who are undocumented. (Hillary Clinton) said don’t do it." / 0 ✗ (1)
# Test: 76000  76% (178m 44s) average_accuracy=0.5240 average_loss=1.0370 "Seventy percent of the people in the state of New Jersey want marriage equality." / 0 ✓
# Train: 77000  77% (181m 20s) average_accuracy=0.5380 average_loss=0.9411 McCain voted 19 times against a minimum-wage increase. / 1 ✗ (2)
# Test: 77000  77% (181m 20s) average_accuracy=0.5520 average_loss=0.9834 Parking lot carjackers are placing flyers or $100 bills on the windows of automobiles, then taking the cars when drivers step out of their vehicles to remove them. / 1 ✗ (0)
# Train: 78000  78% (184m 7s) average_accuracy=0.5160 average_loss=1.0029  “America’s economy achieves 3 percent growth for the first time in 13 years."  / 1 ✗ (0)
# Test: 78000  78% (184m 7s) average_accuracy=0.5230 average_loss=1.0878 He's been endorsed by "every major newspaper here in the state of Texas." / 0 ✗ (2)
# Train: 79000  79% (186m 56s) average_accuracy=0.5220 average_loss=0.9783 John Hagee calls for "prosecuting women who say God’s name during intercourse." / 1 ✗ (0)
# Test: 79000  79% (186m 56s) average_accuracy=0.5130 average_loss=0.9848 "Once again, a police officer has been killed with an illegal gun from Georgia – a state that last year did the NRA’s bidding and weakened its already lax gun laws." / 0 ✗ (1)
# Train: 80000  80% (189m 45s) average_accuracy=0.5560 average_loss=0.9723 New U.S. $5 and $10 bills contain  printing errors. / 0 ✓
# Test: 80000  80% (189m 45s) average_accuracy=0.5590 average_loss=0.9838 Hillary Clinton was arrested by the FBI on 1 April 2016. / 0 ✓
# Train: 81000  81% (192m 40s) average_accuracy=0.5250 average_loss=0.9658 Photograph shows a "thank you" sign to Jews from the Chinese Restaurant Association of the United States. / 0 ✓
# Test: 81000  81% (192m 40s) average_accuracy=0.5540 average_loss=0.9394 "All of this [provisions of the new U.S. Nuclear Posture Review ] is attributed to some imaginary plans of Russia that Pentagon strategists talk about – that we plan to use tactical nuclear weapons or, using conventional forces, invade somewhere in the Baltic countries or Poland. In retaliation, the Americans intend to attack us with strategic nuclear weapons. It is sheer lunacy!” / 1 ✓
# Train: 82000  82% (195m 31s) average_accuracy=0.5090 average_loss=0.9950 Says Supreme Court rival Michael Screnock "is running with the Koch brothers support." / 0 ✗ (1)
# Test: 82000  82% (195m 31s) average_accuracy=0.5430 average_loss=0.9653 “Let there be no doubt: If the bill is passed, thousands of federal offenders, including violent felons and sex offenders, will be released earlier than they would be under current law.” / 0 ✗ (1)
# Train: 83000  83% (198m 31s) average_accuracy=0.5090 average_loss=1.1093  Claims Hillary Clinton "had her emails — 33,000 emails — acid washed ... a very expensive process."  / 0 ✓
# Test: 83000  83% (198m 31s) average_accuracy=0.5000 average_loss=1.0600 Taxpayers paid more than $40,000 for Sasha and Malia Obama's state dinner dresses.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Sasha and Malia Obama wore dresses to a state dinner that cost almost $20,000 each.																			Collected via e-mail, March 2016 / 1 ✓
# Train: 84000  84% (201m 7s) average_accuracy=0.5510 average_loss=0.9597 A nightclub in Amsterdam is hosting a "Blood Rave" event with real blood. / 0 ✓
# Test: 84000  84% (201m 7s) average_accuracy=0.5520 average_loss=0.9251 Cargo lost in the Titanic's sinking led to the creation of the Cinco de Mayo observance. / 0 ✓
# Train: 85000  85% (203m 50s) average_accuracy=0.5250 average_loss=0.9894 Says Beto O'Rourke "voted in favor of a $10 a barrel tax on every barrel of oil produced in the state of Texas." / 0 ✗ (1)
# Test: 85000  85% (203m 50s) average_accuracy=0.5690 average_loss=0.9223 Says the Clinton Foundation "accepted millions and millions of dollars from governments like Algeria, Saudi Arabia, Oman and the United Arab Emirates," which violated "a ban on all contributions to the Foundation from foreign nations." / 1 ✓
# Train: 86000  86% (206m 25s) average_accuracy=0.5100 average_loss=0.9474 Leaked DNC e-mails from May 2016 reveal a plot to contrive fake stories about Donald Trump groping women.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 																												Collected via Facebook, October 2016 / 1 ✗ (0)
# Test: 86000  86% (206m 25s) average_accuracy=0.5500 average_loss=0.9674 Says 642,000 crimes were committed against Texans by criminal immigrants in a recent seven-year period. / 1 ✗ (0)
# Train: 87000  87% (209m 5s) average_accuracy=0.5370 average_loss=0.9680 "The federal government owns tens of thousands of properties that are vacant or underused." / 0 ✗ (2)
# Test: 87000  87% (209m 5s) average_accuracy=0.5350 average_loss=0.9506 A Navy Destroyer crashed into a building in downtown Houston after Hurricane Harvey flooded the city in August 2017. / 0 ✓
# Train: 88000  88% (211m 42s) average_accuracy=0.5340 average_loss=0.9689 California is leading the nation in holding drug companies accountable and fighting prescription drug prices. / 1 ✓
# Test: 88000  88% (211m 42s) average_accuracy=0.5550 average_loss=0.9458 the number one forex earner in Kenya today is remittances from the diaspora / 0 ✗ (2)
# Train: 89000  89% (214m 5s) average_accuracy=0.5510 average_loss=0.9672 "Oprah tells Fox News host ‘all white people have to die.’" / 0 ✓
# Test: 89000  89% (214m 5s) average_accuracy=0.5230 average_loss=0.9462 Photographs show Russian President Vladimir Putin taking a lollipop from a child. / 0 ✓
# Train: 90000  90% (216m 19s) average_accuracy=0.5230 average_loss=1.0224 Says Kelly Ayotte voted to "fix background checks." / 0 ✗ (1)
# Test: 90000  90% (216m 19s) average_accuracy=0.5460 average_loss=0.9750 A video showing Indian soldiers skydiving? / 0 ✓
# Train: 91000  91% (218m 34s) average_accuracy=0.5640 average_loss=0.9599 Says of MS-13 gang members, "We are getting them out of our country by the thousands." / 0 ✗ (1)
# Test: 91000  91% (218m 34s) average_accuracy=0.5380 average_loss=1.0187 Says a group "estimates that the annual cost to Oregon taxpayers for government services to illegal aliens, after any income tax revenue from them, is $1 billion." / 1 ✓
# Train: 92000  92% (220m 50s) average_accuracy=0.5410 average_loss=0.9871 "This is not a joke: the president wants to house illegal aliens on our nation’s military installations." / 0 ✗ (1)
# Test: 92000  92% (220m 50s) average_accuracy=0.5420 average_loss=0.9679 A video shows Muslims rampaging through Paris.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Total News Blackout of Horrific Riots throughout Paris as Muslims rampage the city
#
# 																			Collected via Youtube, May 2016 / 0 ✓
# Train: 93000  93% (223m 15s) average_accuracy=0.5340 average_loss=0.9868  “Today, we import nearly $800 billion more in goods than we export.”  / 1 ✗ (0)
# Test: 93000  93% (223m 15s) average_accuracy=0.5060 average_loss=0.9784 Singer Olivia Newton-John hovers close to death due to a recurring bout of cancer and has only weeks to live. / 0 ✗ (1)
# Train: 94000  94% (225m 45s) average_accuracy=0.5480 average_loss=0.9554 Sen. Arlen Specter's party switch could "end up giving Republicans the ability to filibuster judicial nominees at the Judiciary Committee level so that the nominees never get out of committee." / 1 ✓
# Test: 94000  94% (225m 45s) average_accuracy=0.5400 average_loss=0.9403 Children who witness domestic violence are "twice as likely to commit it themselves." / 1 ✓
# Train: 95000  95% (228m 8s) average_accuracy=0.5300 average_loss=1.0402 Obama's wife wrote a paper in college that said America was a nation founded on "crime and hatred" and that whites in America are "ineradicably racist." / 0 ✓
# Test: 95000  95% (228m 8s) average_accuracy=0.5330 average_loss=0.9944 In early January 2019, all speed cameras on the M1 and M25 motorways in England were simultaneously activated, with a uniform speed limit of 72 miles per hour. / 0 ✓
# Train: 96000  96% (230m 44s) average_accuracy=0.5140 average_loss=1.0575 In August 2017, the owner of a hotel in Arosa, Switzerland posted signs imposing restrictions on Jewish guests, including asking them to shower before using the hotel swimming pool. / 0 ✗ (2)
# Test: 96000  96% (230m 44s) average_accuracy=0.5150 average_loss=1.0101 "Ninety percent of Americans want our background check system strengthened and expanded to cover more gun sales." / 1 ✗ (2)
# Train: 97000  97% (233m 18s) average_accuracy=0.4580 average_loss=1.1350 "The top 1 percent pay 45 percent of all taxes in the country." / 1 ✓
# Test: 97000  97% (233m 18s) average_accuracy=0.5020 average_loss=1.0017 Certain travelers who used American or Southwest Airlines can collect money as part of a consolidated lawsuit settlement. / 1 ✓
# Train: 98000  98% (235m 42s) average_accuracy=0.4690 average_loss=1.0202 "According to observers, the elections were democratic and open." / 0 ✓
# Test: 98000  98% (235m 42s) average_accuracy=0.4920 average_loss=0.9957 “The percentage of Americans who live out their religion on a weekly basis — praying, going to church, reading and believing in the Bible — has remained remarkably consistent over the decades, even as the population of the United States has grown by leaps and bounds." / 0 ✗ (1)
# Train: 99000  99% (238m 11s) average_accuracy=0.4760 average_loss=1.1001 A photograph captures a cheerleader suffering an unfortunate bout of diarrhea in mid-air as her horrified teammates watch. / 0 ✓
# Test: 99000  99% (238m 11s) average_accuracy=0.4770 average_loss=1.2181 Under the North American Free Trade Agreement, "we lost thousands of plants." / 1 ✓
# Train: 100000  100% (240m 47s) average_accuracy=0.5140 average_loss=0.9705 Donald Trump campaign spokeswoman Katrina Pierson was arrested for shoplifting and continued to collect unemployment benefits while working.
#
#
#
#
# 						See Example(s)
#
#
#
#
#
# Trump spokeswoman Katrina Pierson is a CRIMINAL! Shoplifting and unemployment fraud to the tune of $11,000 #TRUMPSUX pic.twitter.com/1uTlWBTC9S
# — James Troy EX-GOP (@jamestroy34) August 13, 2016
#
#
#
# @CNN Katrina Pierson was arrested for shoplifting. She collected 11k and continued to work
#
# — Alex Stavropoulos (@AlexTavro) August 14, 2016
#
#
# 																			Collected via Twitter, August 2016 / 0 ✗ (1)
# Test: 100000  100% (240m 47s) average_accuracy=0.5340 average_loss=0.9964 Judge Neil Gorsuch "has cavalierly referred to contraceptive use ... as ‘the wrongdoing of others.'” / 0 ✗ (1)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(all_train_accuracies)
plt.plot(all_test_accuracies)
plt.title('Q2b (i) claim only')
plt.ylabel('Accuracy')
plt.xlabel('Epochs (by thousand)')
plt.legend(['Train Accuracy', 'Test Accuracy'], loc='upper left')

# %%
all_train_accuracies
# Out:
# [0.4230000000000001,
#  0.44099999999999995,
#  0.436,
#  0.48200000000000015,
#  0.4970000000000002,
#  0.5029999999999999,
#  0.4949999999999991,
#  0.4859999999999999,
#  0.48900000000000027,
#  0.4970000000000004,
#  0.468,
#  0.5000000000000002,
#  0.5179999999999995,
#  0.49500000000000005,
#  0.5030000000000011,
#  0.5099999999999991,
#  0.498999999999999,
#  0.521,
#  0.5270000000000007,
#  0.4910000000000001,
#  0.5430000000000003,
#  0.5200000000000016,
#  0.5199999999999996,
#  0.5849999999999994,
#  0.5319999999999989,
#  0.5020000000000001,
#  0.5350000000000004,
#  0.5610000000000005,
#  0.5099999999999997,
#  0.5249999999999998,
#  0.5189999999999989,
#  0.537,
#  0.5310000000000002,
#  0.5409999999999998,
#  0.5029999999999988,
#  0.5130000000000002,
#  0.5349999999999996,
#  0.54,
#  0.556,
#  0.5479999999999998,
#  0.5420000000000004,
#  0.5749999999999997,
#  0.5320000000000005,
#  0.5879999999999997,
#  0.5309999999999998,
#  0.5260000000000001,
#  0.5419999999999986,
#  0.5400000000000003,
#  0.5420000000000001,
#  0.49700000000000044,
#  0.494,
#  0.4979999999999997,
#  0.5149999999999998,
#  0.5349999999999996,
#  0.5080000000000013,
#  0.4979999999999998,
#  0.5279999999999992,
#  0.5379999999999988,
#  0.4990000000000001,
#  0.5279999999999991,
#  0.5379999999999998,
#  0.5430000000000005,
#  0.5299999999999999,
#  0.4729999999999999,
#  0.5049999999999997,
#  0.5400000000000007,
#  0.5300000000000006,
#  0.494,
#  0.5390000000000005,
#  0.5399999999999998,
#  0.49800000000000033,
#  0.5349999999999988,
#  0.5509999999999995,
#  0.5440000000000005,
#  0.5489999999999999,
#  0.5250000000000009,
#  0.5380000000000009,
#  0.5160000000000006,
#  0.5220000000000004,
#  0.5560000000000005,
#  0.5249999999999994,
#  0.5090000000000001,
#  0.5090000000000001,
#  0.5509999999999998,
#  0.5249999999999998,
#  0.5099999999999997,
#  0.5370000000000011,
#  0.5340000000000014,
#  0.5510000000000012,
#  0.5230000000000009,
#  0.5640000000000006,
#  0.5409999999999998,
#  0.5339999999999984,
#  0.5479999999999998,
#  0.5300000000000005,
#  0.5140000000000002,
#  0.458,
#  0.469,
#  0.476,
#  0.5140000000000007]

# %%
all_test_accuracies
# Out:
# [0.4400000000000001,
#  0.40900000000000014,
#  0.431,
#  0.463,
#  0.5139999999999995,
#  0.5149999999999993,
#  0.48,
#  0.482,
#  0.5250000000000009,
#  0.49300000000000116,
#  0.49800000000000016,
#  0.511000000000001,
#  0.5279999999999991,
#  0.5380000000000001,
#  0.5210000000000011,
#  0.5149999999999981,
#  0.5180000000000007,
#  0.5149999999999989,
#  0.5209999999999995,
#  0.5129999999999998,
#  0.5600000000000003,
#  0.5270000000000005,
#  0.5439999999999996,
#  0.5310000000000014,
#  0.5389999999999996,
#  0.5240000000000005,
#  0.5340000000000005,
#  0.5159999999999992,
#  0.5309999999999998,
#  0.5249999999999997,
#  0.5030000000000003,
#  0.5169999999999993,
#  0.527,
#  0.524000000000001,
#  0.4809999999999999,
#  0.5760000000000007,
#  0.5249999999999991,
#  0.5139999999999989,
#  0.5529999999999995,
#  0.5549999999999989,
#  0.5140000000000001,
#  0.5950000000000002,
#  0.5460000000000006,
#  0.5620000000000009,
#  0.5250000000000006,
#  0.5209999999999989,
#  0.526,
#  0.5270000000000005,
#  0.5039999999999998,
#  0.519,
#  0.4589999999999999,
#  0.5019999999999999,
#  0.4939999999999996,
#  0.5229999999999999,
#  0.5490000000000007,
#  0.5219999999999991,
#  0.49600000000000155,
#  0.5460000000000006,
#  0.5050000000000007,
#  0.5309999999999995,
#  0.5410000000000003,
#  0.5320000000000003,
#  0.5189999999999999,
#  0.4729999999999999,
#  0.4980000000000002,
#  0.5200000000000005,
#  0.5269999999999994,
#  0.48900000000000005,
#  0.5369999999999996,
#  0.4980000000000001,
#  0.5620000000000006,
#  0.5280000000000002,
#  0.523,
#  0.5210000000000009,
#  0.5560000000000003,
#  0.5240000000000014,
#  0.5519999999999998,
#  0.522999999999999,
#  0.5129999999999993,
#  0.5590000000000003,
#  0.5539999999999998,
#  0.5430000000000007,
#  0.5,
#  0.5520000000000007,
#  0.568999999999999,
#  0.55,
#  0.5349999999999998,
#  0.5550000000000004,
#  0.5230000000000005,
#  0.5460000000000009,
#  0.5379999999999998,
#  0.5420000000000015,
#  0.5059999999999999,
#  0.54,
#  0.5330000000000009,
#  0.515,
#  0.5019999999999993,
#  0.492,
#  0.4769999999999999,
#  0.5339999999999991]

# %%
d_model = 50
heads = 2
N = 6
n_categories = 3
model = Transformer(d_model, N, heads)
classifier = Classifier(d_model, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4

optim = torch.optim.Adam(model.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)

# %%
# Keep track of losses for plotting
current_loss = 0
all_losses = []

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]
train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0
all_train_losses_2 = []
all_train_accuracies_2 = []
all_test_losses_2 = []
all_test_accuracies_2 = []
count = 0
for iter in range(1, n_iters + 1):
    train_line_tensor, train_category_tensor, train_line, train_category, train_id = sampleClaimAndClaimant(train_data)
    train_output, train_loss = train(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_line_tensor, test_category_tensor, test_line, test_category, test_id = sampleClaimAndClaimant(test_data)
    test_output, test_loss = train(test_category_tensor, test_line_tensor, update=False)
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_line, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_line, test_guess_category, test_correct))
        all_train_losses_2.append(train_cumulative_loss / plot_every)
        all_train_accuracies_2.append(average_train_accuracy)
        all_test_losses_2.append(test_cumulative_loss / plot_every)
        all_test_accuracies_2.append(average_test_accuracy)
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
# Out:
# Train: 1000  1% (0m 53s) average_accuracy=0.4420 average_loss=4.4052 Tendulkar, Kohli, Indian celebrities join BJP multiple sources / 2 ✗ (0)
# Test: 1000  1% (0m 53s) average_accuracy=0.4300 average_loss=3.6530  "We have no [trade] deficit [with Canada], but that doesn't include energy and timber. But when you do we lose $17 billion a year."  Donald Trump / 1 ✗ (0)
# Train: 2000  2% (1m 46s) average_accuracy=0.4650 average_loss=1.5501 Acclaimed actor Morgan Freeman died in October 2017 at the age of 80.  / 0 ✓
# Test: 2000  2% (1m 46s) average_accuracy=0.4460 average_loss=1.6631 Bowe Bergdahl wanders off during court-martial Duffel Blog / 0 ✓
# Train: 3000  3% (2m 39s) average_accuracy=0.4710 average_loss=1.4555 No, these photos do not show Muslims being tortured and killed in Myanmar multiple sources / 0 ✓
# Test: 3000  3% (2m 39s) average_accuracy=0.4770 average_loss=1.6167 A video shows U.S. President Donald Trump removing his hat and revealing that he's bald.  / 0 ✓
# Train: 4000  4% (3m 33s) average_accuracy=0.4550 average_loss=2.6613 President Obama has cancelled all upcming appearances at campaign events for Hillary Clinton in October 2016.  / 0 ✓
# Test: 4000  4% (3m 33s) average_accuracy=0.4750 average_loss=2.6020 Says Hillary Clinton is proposing "destroying Medicare for seniors." Donald Trump Jr. / 0 ✓
# Train: 5000  5% (4m 29s) average_accuracy=0.4660 average_loss=1.3804 Atlanta now has as many visitors as Las Vegas, San Diego and Los Angeles. Orlando, Fla., and New York City still have more visitors. Kasim Reed / 1 ✓
# Test: 5000  5% (4m 29s) average_accuracy=0.4950 average_loss=1.3435  Virginia Lt. Gov. Ralph Northam was the “deciding vote” in “favor of sanctuary cities that let dangerous illegal immigrants back on the streets.”  Ed Gillespie / 1 ✗ (0)
# Train: 6000  6% (5m 27s) average_accuracy=0.4790 average_loss=1.1231 A photograph shows Canadian Prime Minster Justin Trudeau kissing opposition leader Thomas Mulcair.  / 0 ✓
# Test: 6000  6% (5m 27s) average_accuracy=0.4800 average_loss=1.0937 President Barack Obama’s policies "have resulted in gas prices being reduced from $3.07 per gallon when he was sworn in in 2009 to $2.30 today." Bobby  Scott / 1 ✗ (0)
# Train: 7000  7% (6m 24s) average_accuracy=0.4810 average_loss=1.4670 The man accused of opening fire on hundreds of people in a Las Vegas casino in October 2017 was spotted at an anti-Trump protest two months earlier.  / 0 ✓
# Test: 7000  7% (6m 24s) average_accuracy=0.4890 average_loss=1.4821 Restaurant workers at Smithfield's Chicken & Barbeque Jones Sausage in Raleigh sang "fuck the police" at visiting officers.  / 0 ✓
# Train: 8000  8% (7m 23s) average_accuracy=0.4830 average_loss=1.4227 President Trump cancelled Michelle Obama's school lunch program in October 2018.  / 0 ✗ (1)
# Test: 8000  8% (7m 23s) average_accuracy=0.4860 average_loss=1.3348 "More than half of all drivers' licenses issued in California this year have gone to illegal aliens." NumbersUSA / 0 ✗ (1)
# Train: 9000  9% (8m 22s) average_accuracy=0.4590 average_loss=1.4177 “We have reduced our CO2 footprint by over 18 percent, almost 20 percent, from 2000 to 2014.” Scott Pruitt / 1 ✓
# Test: 9000  9% (8m 22s) average_accuracy=0.4610 average_loss=1.2485 Says a group "estimates that the annual cost to Oregon taxpayers for government services to illegal aliens, after any income tax revenue from them, is $1 billion." Oregon Republican Party / 1 ✓
# Train: 10000  10% (9m 21s) average_accuracy=0.4840 average_loss=1.0618 "According to the state of Florida, you are almost twice as likely to be attacked by an alligator than by someone who happens to carry a conceal-and-carry permit." Florida Students for Concealed Carry / 0 ✗ (1)
# Test: 10000  10% (9m 21s) average_accuracy=0.5030 average_loss=1.0583 "The Earth is not warming." Barry Smitherman / 0 ✓
# Train: 11000  11% (10m 19s) average_accuracy=0.5040 average_loss=1.1012 “That is an unprecedented thing. They are attempting to bring high treason charges against a person for what he did publicly and for performing his professional duties. I haven’t seen anything like this in a long time.” Vladimir Putin / 1 ✗ (0)
# Test: 11000  11% (10m 19s) average_accuracy=0.4890 average_loss=1.0426 "Suicide is the second-leading cause of death among 15-19 year olds and 25-34 year olds in Missouri." Tracy McCreery / 1 ✗ (2)
# Train: 12000  12% (11m 19s) average_accuracy=0.4900 average_loss=1.2065 Elephant carrying thirsty lion cub Facebook user / 0 ✓
# Test: 12000  12% (11m 19s) average_accuracy=0.4810 average_loss=1.2038 Under the North American Free Trade Agreement, "we lost millions of jobs." Donald Trump / 0 ✓
# Train: 13000  13% (12m 18s) average_accuracy=0.4520 average_loss=1.7744 A bill from U.S. Rep. Ted Yoho attempts to restrict the administration's ability to conduct national security and criminal background checks on undocumented immigrants. Barack Obama / 0 ✗ (1)
# Test: 13000  13% (12m 18s) average_accuracy=0.4850 average_loss=1.4390 "Condemning violence against the police and urging support for the police" is "markedly absent" from President Barack Obama’s public remarks. William Johnson / 0 ✓
# Train: 14000  14% (13m 17s) average_accuracy=0.4810 average_loss=1.0405 The Republican Party has "21 percent party ID and shrinking." Democratic National Committee / 1 ✓
# Test: 14000  14% (13m 17s) average_accuracy=0.4880 average_loss=1.0028 Ilhan Omar took part in her swearing-in to the Minnesota House of Representatives with her hand on a Quran.  / 1 ✓
# Train: 15000  15% (14m 14s) average_accuracy=0.4930 average_loss=1.1283 Whoopi Goldberg was arrested following an FBI investigation into an alleged dog-breeding operation.  / 0 ✓
# Test: 15000  15% (14m 14s) average_accuracy=0.5100 average_loss=1.0171 Sarah Palin said that America was not to blame for slavery, and that "the negroes" liked it.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I saw an article stating that Sarah Palin said "slavery wasn't our fault, the negroes liked it." That can't be true, can it?																			Collected via e-mail, May 2016  / 0 ✓
# Train: 16000  16% (15m 13s) average_accuracy=0.4830 average_loss=1.0535 "Six people in Florida die as a result of (not expanding Medicaid) every day." Charlie Crist / 1 ✓
# Test: 16000  16% (15m 13s) average_accuracy=0.5060 average_loss=0.9789 "At some point in their lives, 99% of women use birth control." Susan Happ / 1 ✓
# Train: 17000  17% (16m 10s) average_accuracy=0.5020 average_loss=1.0420 Obamacare medical device tax "has led to the loss of thousands of jobs" in U.S. Ted Poe / 0 ✗ (1)
# Test: 17000  17% (16m 10s) average_accuracy=0.4950 average_loss=1.0415 Notorious mobster Al Capone demanded an inquiry into whether his gang was surveilled or infiltrated by the Department of Justice.  / 0 ✓
# Train: 18000  18% (17m 9s) average_accuracy=0.5030 average_loss=1.0529 Marco Rubio "has the No. 1 absentee record in the United States" Senate. Donald Trump / 0 ✗ (1)
# Test: 18000  18% (17m 9s) average_accuracy=0.5140 average_loss=0.9873 Comedian Kathy Griffin was shot and killed while trying to escape custody.  / 0 ✓
# Train: 19000  19% (18m 10s) average_accuracy=0.4260 average_loss=1.4262 A photograph shows President Barack Obama bowing to Iran's supreme leader Ali Khamenei.  / 0 ✓
# Test: 19000  19% (18m 10s) average_accuracy=0.4880 average_loss=1.1265 Wisconsin is "dead-last in creating new businesses" for "three years in a row." Andy Gronik / 0 ✗ (1)
# Train: 20000  20% (19m 10s) average_accuracy=0.5310 average_loss=1.0029 "Obama has proposed 442 tax hikes since taking office." Americans For Tax Reform / 0 ✗ (1)
# Test: 20000  20% (19m 10s) average_accuracy=0.5160 average_loss=0.9931 On attacks by Republicans that various programs in the economic stimulus plan are not stimulative, "If you add all that stuff up, it accounts for less than 1 percent of the overall package." Barack Obama / 0 ✗ (1)
# Train: 21000  21% (20m 8s) average_accuracy=0.5370 average_loss=1.1231 "Only three in 10 young Americans under 30 -- 30 percent under 30 -- have full-time work." Ron Meyer / 1 ✓
# Test: 21000  21% (20m 8s) average_accuracy=0.5170 average_loss=0.9716 The federal deficit would pay for 40 gallons of "New Hampshire maple syrup" for everyone in the United States. Kelly  Ayotte / 1 ✓
# Train: 22000  22% (21m 5s) average_accuracy=0.5030 average_loss=1.0725 Various restaurants around the world were shut down for serving  for serving human meat.  / 1 ✗ (0)
# Test: 22000  22% (21m 5s) average_accuracy=0.5420 average_loss=1.0710 Donald Trump promised on Twitter that his first act as president would be to pardon Dylann Roof.  / 0 ✓
# Train: 23000  23% (22m 2s) average_accuracy=0.5140 average_loss=0.9829 "Since taking office I have been very strict on Commercial Aviation. Good news - it was just reported that there were Zero deaths in 2017, the best and safest year on record!" Donald Trump / 0 ✗ (1)
# Test: 23000  23% (22m 2s) average_accuracy=0.4920 average_loss=1.0345 Heather Holland, a 38-year-old grade school teacher in Willow Park, Texas, died because she couldn't afford the co-pay for her flu medication.  / 0 ✗ (1)
# Train: 24000  24% (22m 59s) average_accuracy=0.4900 average_loss=1.0644  "Many people are saying that the Iranians killed the scientist who helped the U.S. because of Hillary Clinton's hacked emails."  Donald Trump / 0 ✓
# Test: 24000  24% (22m 59s) average_accuracy=0.5480 average_loss=0.9604 "The centerpiece of Senator McCain's education policy is to increase the voucher program in D.C. by 2,000 slots." Barack Obama / 0 ✓
# Train: 25000  25% (23m 57s) average_accuracy=0.5320 average_loss=1.1222 Nike captured an amazing photo of the coin toss before the 2015 College Football Playoff championship game.  / 0 ✓
# Test: 25000  25% (23m 57s) average_accuracy=0.5430 average_loss=1.0769 He's been endorsed by "every major newspaper here in the state of Texas." Barack Obama / 0 ✗ (2)
# Train: 26000  26% (24m 55s) average_accuracy=0.5250 average_loss=1.0599 President Obama fired several military officers for disobeying his order to destroy Charleston as part of a “false flag” attack.  / 0 ✓
# Test: 26000  26% (24m 55s) average_accuracy=0.5250 average_loss=1.0446 Adolf Hitler was named 'Man of the Year' by Time magazine in 1938.  / 0 ✗ (2)
# Train: 27000  27% (25m 53s) average_accuracy=0.5540 average_loss=0.9635 A newspaper article from 2015 reported that comedian Michelle Wolf had been arrested for bestiality  / 0 ✓
# Test: 27000  27% (25m 53s) average_accuracy=0.5330 average_loss=0.9867 Says that Andrew Gillum said, "Police and prisons have no place in justice." Ron DeSantis / 0 ✗ (1)
# Train: 28000  28% (26m 49s) average_accuracy=0.5240 average_loss=1.0123 Video shows China has opened an 880-kilometre highway to Pakistan Multiple sources / 0 ✓
# Test: 28000  28% (26m 49s) average_accuracy=0.5300 average_loss=1.0690 "For what it would cost the (National) Guard to make just two arrests at the border, we could give a homeless veteran permanent housing for an entire year." Ruben Gallego / 1 ✓
# Train: 29000  28% (27m 47s) average_accuracy=0.5410 average_loss=0.9960 Rhode Island "charter schools are nationally recognized as outperforming their counterparts across the country." Rose Mary Grant / 1 ✓
# Test: 29000  28% (27m 47s) average_accuracy=0.5420 average_loss=0.9901 McCain's energy plan is a "single-answer proposition" — new domestic oil drilling. Brian Schweitzer / 0 ✓
# Train: 30000  30% (28m 45s) average_accuracy=0.5590 average_loss=1.1138 Says "The idea of one casino per tribe is a false one." Ken Tanner / 0 ✗ (1)
# Test: 30000  30% (28m 45s) average_accuracy=0.5630 average_loss=1.0238 Says a progressive income tax proposal from Democratic governor candidate J.B. Pritzker "is wholly regressive." Evelyn Sanguinetti / 1 ✗ (0)
# Train: 31000  31% (29m 43s) average_accuracy=0.5700 average_loss=0.9963 "He admits he still doesn't know how to use a computer, can't send an e-mail." Barack Obama / 0 ✗ (1)
# Test: 31000  31% (29m 43s) average_accuracy=0.5720 average_loss=0.9667 There was "serious voter fraud" in California. Donald Trump / 0 ✓
# Train: 32000  32% (30m 40s) average_accuracy=0.5980 average_loss=1.0074 The projected revenue from the Mayweather/Pacquiao fight is "larger than the annual GDP of 29 different countries." Jim Lampley / 1 ✗ (0)
# Test: 32000  32% (30m 40s) average_accuracy=0.5880 average_loss=0.9590 "We now have about one-third of New York’s population on Medicaid." John Faso / 1 ✗ (2)
# Train: 33000  33% (31m 35s) average_accuracy=0.5890 average_loss=0.9290 Entertainers Kid Rock and Ted Nugent have raised more than $10 million to fight the War on Christmas.  / 1 ✗ (0)
# Test: 33000  33% (31m 35s) average_accuracy=0.5680 average_loss=0.9943 "Muslims in America have been subjected to more insults, attacks and hate crimes in the last two or three years than ever before, specifically more than after 9-11." Omar Rachid / 1 ✓
# Train: 34000  34% (32m 32s) average_accuracy=0.6060 average_loss=0.9094 CIA Deputy Director Gina Haspel has a warrant for her arrest in Germany.  / 0 ✓
# Test: 34000  34% (32m 32s) average_accuracy=0.5730 average_loss=0.9372 Residents in Waco, Texas booed Bill Nye The Science Guy for saying that the moon reflects light from the sun.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Have seen this about Bill Nye the Science Guy in Waco, Texas, being booed for saying moon reflects the Sun. Is this true?																			Collected via e-mail, December 2015  / 0 ✗ (1)
# Train: 35000  35% (33m 30s) average_accuracy=0.6080 average_loss=1.0165 “World Anti-Doping Agency president Craig Reedie says he is 'disappointed' at the organization’s failure to access Moscow laboratory data as the deadline for the step elapsed at the end of 2018.” Russia Today (RT) / 0 ✗ (1)
# Test: 35000  35% (33m 30s) average_accuracy=0.5740 average_loss=1.0520 A sheriff's department in Florida announced that they would not protect the Miami Dolphins during the 2017 season in retaliation to a player boycott of the National Anthem.  / 0 ✓
# Train: 36000  36% (34m 26s) average_accuracy=0.5560 average_loss=1.0220 "Loopholes in current law prevent ‘Unaccompanied Alien Children’ (UACs) that arrive in the country illegally from being removed." Donald Trump / 0 ✗ (1)
# Test: 36000  36% (34m 26s) average_accuracy=0.5720 average_loss=0.9941  "Obamacare is discouraging people from going to medical school and training to be doctors."  Sen. Ted Cruz  / 1 ✗ (0)
# Train: 37000  37% (35m 22s) average_accuracy=0.5980 average_loss=0.9687 A photograph shows accused Russian spy Mariia Butina in an Oval Office meeting with President Trump.  / 0 ✓
# Test: 37000  37% (35m 22s) average_accuracy=0.6010 average_loss=0.9999 Voter identification laws make it complicated and expensive to get an ID, essentially instituting a modern-day poll tax. American Civil Liberties Union / 1 ✓
# Train: 38000  38% (36m 19s) average_accuracy=0.5910 average_loss=0.9555 Says "the one person (Donald Trump) has suggested that would make a good justice is his sister, who is a court of appeals judge appointed by Bill Clinton. She is a hardcore pro-abortion liberal judge." Ted Cruz / 0 ✗ (1)
# Test: 38000  38% (36m 19s) average_accuracy=0.5810 average_loss=0.9770 "Every county, including Chittenden, has fewer people available for work." Phil Scott / 1 ✗ (0)
# Train: 39000  39% (37m 14s) average_accuracy=0.5820 average_loss=1.0055 We have “a few dozen soldiers there” in the fight against Islamic State Tom Mulcair / 0 ✗ (1)
# Test: 39000  39% (37m 14s) average_accuracy=0.5870 average_loss=0.9988 "Just like when you ran the State Department, $6 billion was missing. How do you miss $6 billion? You ran the State Department, $6 billion was either stolen. They don't know. It's gone, $6 billion." Donald Trump / 1 ✗ (0)
# Train: 40000  40% (38m 8s) average_accuracy=0.6040 average_loss=0.9276 Says under U.S. Sen. Robert Menendez’s watch the nation’s unemployment rate and debt doubled and the federal budget deficit quadrupled. Joseph Kyrillos / 1 ✓
# Test: 40000  40% (38m 8s) average_accuracy=0.5710 average_loss=0.9268 New York state has the "second highest millionaires tax in the nation." Christine Quinn / 1 ✓
# Train: 41000  41% (39m 7s) average_accuracy=0.5520 average_loss=0.9518 You can avoid paying for traffic tickets or establish a new identity by obtaining an International Driver’s License.  / 0 ✓
# Test: 41000  41% (39m 7s) average_accuracy=0.5530 average_loss=0.9586 Says Democratic North Carolina House candidate Dan McCready "took money from the Pelosi crowd" and is "with them" in their agenda and "wants to repeal your tax cut." Mark Harris / 1 ✓
# Train: 42000  42% (40m 3s) average_accuracy=0.5710 average_loss=0.9726 "It’s estimated that 40 percent of all the guns that are sold in the United States occur with no background records check." Tim Kaine / 0 ✗ (1)
# Test: 42000  42% (40m 3s) average_accuracy=0.5740 average_loss=0.9387 Says Florida refused to allow the insurance commissioner to "negotiate lower rates with companies or refuse rates that are too high" under Obamacare. Ted Deutch / 0 ✗ (2)
# Train: 43000  43% (41m 0s) average_accuracy=0.5660 average_loss=1.1355 The average fast food worker is 29, and most fast food workers "are on some form of public assistance." Bill Maher / 1 ✓
# Test: 43000  43% (41m 0s) average_accuracy=0.5760 average_loss=1.0210 A photograph captures a selfie Jimi Hendrix took with Jim Morrison and Bruce Lee.  / 0 ✓
# Train: 44000  44% (41m 57s) average_accuracy=0.5710 average_loss=0.9160 A bipartisan background check amendment "outlawed any (gun) registry.  Plain and simple, right there in the text." Barack Obama / 1 ✗ (2)
# Test: 44000  44% (41m 57s) average_accuracy=0.6010 average_loss=0.9562 The search-and-rescue organization in Syria, the White Helmets, is linked to terrorists.  / 0 ✓
# Train: 45000  45% (42m 53s) average_accuracy=0.5620 average_loss=0.9787 "Charlie Crist allowed college tuition to increase up to 15 percent every year." Rick Scott / 1 ✓
# Test: 45000  45% (42m 53s) average_accuracy=0.5640 average_loss=0.9539 Says "Michael Bennet votes for President Obama's agenda 98 percent of the time. Hardly independent, hardly bipartisan." Ryan Frazier / 1 ✓
# Train: 46000  46% (43m 48s) average_accuracy=0.5700 average_loss=0.9682 E-mail compares George W. Bush's eco-friendly ranch with Al Gore's energy-expending mansion.  / 1 ✗ (2)
# Test: 46000  46% (43m 48s) average_accuracy=0.5720 average_loss=0.9778 “This exciting new project will encourage our colleagues and fellow citizens to think critically, and to provide a large platform where this can still happen, free of censorship. We need to be creative, to start our own watchdog organizations, and restore our basic constitutional freedoms.The key to being able to do that, starts with the fight for freedom of speech.” Unknown / 0 ✗ (1)
# Train: 47000  47% (44m 44s) average_accuracy=0.5740 average_loss=0.9666 Texas has the sixth-highest property taxes in the nation. Jeff Judson / 1 ✓
# Test: 47000  47% (44m 44s) average_accuracy=0.6000 average_loss=0.9403 "Bike lanes and sidewalks have been proven to reduce crashes by up to 38 percent on Austin’s streets." Bike Austin / 1 ✓
# Train: 48000  48% (45m 39s) average_accuracy=0.5860 average_loss=0.9011 Says a challenge called "Momo" is appearing online in apps and children’s programs and threatens kids in an attempt to force them into performing harmful acts. Facebook posts / 0 ✓
# Test: 48000  48% (45m 39s) average_accuracy=0.6080 average_loss=0.9283 "When I got to work as Secretary of State, I opted for convenience to use my personal email account, which was allowed by the State Department." Hillary Clinton / 1 ✓
# Train: 49000  49% (46m 34s) average_accuracy=0.6050 average_loss=0.9211 "Illegal immigration costs our country more than $113 billion a year." Donald Trump / 1 ✓
# Test: 49000  49% (46m 34s) average_accuracy=0.5950 average_loss=0.9306 Says Donald Trump’s health care policies have "left millions more Americans uninsured since he took office." Julián Castro / 1 ✓
# Train: 50000  50% (47m 31s) average_accuracy=0.5680 average_loss=0.9972 “When I did it [established a program to prosecute parents whose kids missed school], I knew I was going to take a political hit. And the people around me said, ‘Don’t do it, because you are gonna pay a price for this in terms of whatever future you want in politics.’ And I said: ‘Look, I’m prepared to play the bad guy on this. I do not intend to put any parent in jail.’ And no parent went to jail." Kamala D. Harris / 0 ✗ (1)
# Test: 50000  50% (47m 31s) average_accuracy=0.5740 average_loss=0.9772 Cell phone companies began charging users for SMS emojis (emoticons) in February 2016.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Are cellular companies charging for emoji's?
#
#
#
#
#
# .@EE you charge an emoji in a text message as if it was a picture? WHAT A RIP OFF! No justification EE
# Please share everybody
# — Dorina (@Dorina335) February 25, 2016
#
# 																			Collected via e-mail and Twitter, March 2016  / 0 ✗ (1)
# Train: 51000  51% (48m 25s) average_accuracy=0.5530 average_loss=0.9961 "Docs: Wisconsin Governor Scott Walker took $1 million from a pro-Putin Ukrainian businessman—last election cycle." Tweets / 1 ✓
# Test: 51000  51% (48m 25s) average_accuracy=0.5880 average_loss=0.9742 "Ohioans want an end to pay-to-play politics." Ed FitzGerald / 1 ✗ (0)
# Train: 52000  52% (49m 21s) average_accuracy=0.6130 average_loss=0.8819 "Drug prices in this country actually came down last year for the first time in 50 years. That’s because Donald Trump’s president." Mick Mulvaney / 0 ✗ (1)
# Test: 52000  52% (49m 21s) average_accuracy=0.5870 average_loss=0.9436 "In American history since 9/11, we've had 85 major attacks in our country, 73 percent of them have been by white nationalist hate groups." Cory Booker / 1 ✓
# Train: 53000  53% (50m 18s) average_accuracy=0.5760 average_loss=0.9393 Drummer Ginger Baker sodomized a burglar with his cane after catching him in his house.  / 0 ✓
# Test: 53000  53% (50m 18s) average_accuracy=0.5750 average_loss=0.9277 "Joe Biden brought Republicans and Democrats together to pass the 1994 crime bill, putting 100,000 cops on the streets and starting an eight-year drop in crime across the country." Barack Obama / 1 ✓
# Train: 54000  54% (51m 14s) average_accuracy=0.6010 average_loss=0.9445 "30,000 Arizonans may have no choice" on Affordable Care Act coverage. John McCain / 1 ✓
# Test: 54000  54% (51m 14s) average_accuracy=0.5690 average_loss=1.0096 Target.com or Target blocked Israel from accessing and shopping their web site.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									I find this hard to believe and before it is spread like crazy on FB I would love to know if its real... you always come through for me!!
#
# Target.com has made the conscious decision to block IP addresses originating from Israel, as it is one of the top 5 countries from which malicious attacks against our website originate.
#
# link was to this article
# http://www.onlysimchas.com/news/43375/breaking-target-com-blocks-israel
#
#
#
# 																			Collected via e-mail and Twitter, December 2016  / 0 ✗ (1)
# Train: 55000  55% (52m 12s) average_accuracy=0.5900 average_loss=0.9769 Over the past five years, we’ve made significant progress with the provision of infrastructure. More than R1.3 trillion has been invested to build [infrastructure including] hundreds of thousands of new homes… President Cyril Ramaphosa / 1 ✗ (2)
# Test: 55000  55% (52m 12s) average_accuracy=0.6070 average_loss=0.9486 "In France, they have a (surveillance) program a thousandfold more invasive" than the United States. Rand Paul / 1 ✓
# Train: 56000  56% (53m 8s) average_accuracy=0.6170 average_loss=0.8683 Unlike Benghazi, there were no investigations of the 1983 Beirut barracks bombing, none about key aspects of the 9/11 attacks and the Iraq War, and none about embassy attacks under George W. Bush. Viral image / 1 ✓
# Test: 56000  56% (53m 8s) average_accuracy=0.6110 average_loss=0.9048 Limiting labor negotiations to only wages is "how it is for the most part in the private sector." Alberta Darling / 1 ✗ (0)
# Train: 57000  56% (54m 3s) average_accuracy=0.5860 average_loss=0.9792 A GoFundMe page was established to collect donations for embattled Supreme Court nominee Brett Kavanaugh.  / 0 ✗ (2)
# Test: 57000  56% (54m 3s) average_accuracy=0.5780 average_loss=0.9322 "There are more people killed with baseball bats and hammers than are killed with guns." Paul Broun / 0 ✓
# Train: 58000  57% (54m 59s) average_accuracy=0.5820 average_loss=1.0422 An image showing Marilyn Monroe with a cat is a genuine photograph.  / 0 ✓
# Test: 58000  57% (54m 59s) average_accuracy=0.5990 average_loss=0.9319 "The bulk of the problem with the opioid epidemic is the fentanyl and all the synthetic drugs coming across the southern border." Ron DeSantis / 0 ✗ (1)
# Train: 59000  59% (55m 54s) average_accuracy=0.6170 average_loss=0.8714 The health care reform bill "is the largest tax increase in U.S. history." Joe Scarborough / 1 ✗ (0)
# Test: 59000  59% (55m 54s) average_accuracy=0.5840 average_loss=0.9451 Jailed Philippine senator asked Supreme Court to allow visits from ex-lover  / 0 ✓
# Train: 60000  60% (56m 49s) average_accuracy=0.5850 average_loss=0.9694 "Most Planned Parenthood settings are in urban areas, urban areas that have lots of OB/GYNs. ... The folks who don't have access to those cancer screenings live in rural areas. They live in areas where there are not enough physicians." Sen. Bill Cassidy (R-La.) / 1 ✓
# Test: 60000  60% (56m 49s) average_accuracy=0.5950 average_loss=0.9146 Miller County Judge Roy John McNatt wrote a racist memo about black people.  / 1 ✗ (0)
# Train: 61000  61% (57m 44s) average_accuracy=0.6030 average_loss=0.9672 "One out of five of our children live in a family that’s on food stamps." Rick Perry / 1 ✗ (2)
# Test: 61000  61% (57m 44s) average_accuracy=0.5720 average_loss=0.9603 "A little-known unit of the Department of Justice, the Community Relations Service, was deployed to Sanford, FL, following the Trayvon Martin shooting to help organize and manage rallies and protests against George Zimmerman." Judicial Watch / 1 ✓
# Train: 62000  62% (58m 40s) average_accuracy=0.5960 average_loss=0.8964 Pepsi admitted that their soda contains cancer-causing ingredients.  / 0 ✗ (1)
# Test: 62000  62% (58m 40s) average_accuracy=0.5700 average_loss=0.9855 President Obama has signed an executive order banning the possession and sale of Confederate flags.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									Supposedly Obama signed an executive order making it illegal to own a confederate flag on June 23, 2015 to be retro effective 6-18-15. The executive order is 209.																			Collected via e-mail, June 2015  / 0 ✓
# Train: 63000  63% (59m 37s) average_accuracy=0.5830 average_loss=0.8986 Missouri "had the largest amount of millennial Democrats running than any other state in the country." Crystal Quade / 1 ✗ (2)
# Test: 63000  63% (59m 37s) average_accuracy=0.5550 average_loss=1.0040 Chick-fil-A president Dan Cathy announced that the chain would oppose blacks as a marketing ploy.  / 0 ✓
# Train: 64000  64% (60m 32s) average_accuracy=0.5750 average_loss=0.9957  Democratic candidate for governor Stacey Abrams "will let illegal immigrants vote.”  Georgia Republican Party / 0 ✓
# Test: 64000  64% (60m 32s) average_accuracy=0.5570 average_loss=0.9362 Under Ryan plan, "those 54 and younger would receive the same kind of healthcare options now enjoyed by members of Congress." Scott Rigell / 1 ✓
# Train: 65000  65% (61m 28s) average_accuracy=0.5920 average_loss=0.9143 U.S. Marshals are arresting people who have not paid their student loans.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									US Marshals Service arresting people for not paying student loans? As someone who has two large student loans to pay, this is a little scary. Is it true?																			Collected via Email, February 2016  / 0 ✗ (1)
# Test: 65000  65% (61m 28s) average_accuracy=0.5860 average_loss=0.9083 "When you get a commercial pilot’s license, you learn to communicate in English no matter where you are in the world." Don Balfour / 1 ✓
# Train: 66000  66% (62m 22s) average_accuracy=0.6050 average_loss=0.9058 The Jacksonville Jaguars filed for bankruptcy in December 2017 after NFL fans boycotted the league due to player protests.  / 0 ✓
# Test: 66000  66% (62m 22s) average_accuracy=0.5850 average_loss=0.9558 "Limberbutt McCubbins (a five-year-old cat) is a candidate" in the 2016 presidential election. Limberbutt McCubbins / 1 ✓
# Train: 67000  67% (63m 18s) average_accuracy=0.5940 average_loss=0.9290 A billboard along route I-170 near St. Louis, Missouri showed President Donald Trump alongside an excerpt from a well-known Gospel verse.  / 0 ✗ (2)
# Test: 67000  67% (63m 18s) average_accuracy=0.6060 average_loss=0.9392 Obama thinks the national anthem should be "I'd Like to Teach the World to Sing." Chain email / 1 ✗ (0)
# Train: 68000  68% (64m 15s) average_accuracy=0.5820 average_loss=0.9260 Photograph shows the killer Volat-Araneus “flying spider” due to migrate to the UK this year.  / 0 ✓
# Test: 68000  68% (64m 15s) average_accuracy=0.5730 average_loss=0.9622 The ammunition used in the Orlando shooting "is banned by Geneva Convention. It enters the body, spins & explodes." Michael Moore / 1 ✗ (0)
# Train: 69000  69% (65m 10s) average_accuracy=0.6030 average_loss=0.9311 If you tried to pay out $1 trillion by handing it out at $1 per second, it would take more than 31,000 years. Johnny Isakson / 1 ✗ (2)
# Test: 69000  69% (65m 10s) average_accuracy=0.5660 average_loss=0.9525 "Close to half of the voters in America, the only tax they pay is the payroll tax." Marco Rubio / 1 ✓
# Train: 70000  70% (66m 5s) average_accuracy=0.5900 average_loss=0.9099 "Jeff Greene can buy anything" ...  he owns two mansions. Kendrick Meek / 1 ✗ (2)
# Test: 70000  70% (66m 5s) average_accuracy=0.5940 average_loss=0.9150 'Fixer Upper' star Joanna Gaines is pregnant with her fifth child in January 2018.  / 0 ✗ (2)
# Train: 71000  71% (67m 0s) average_accuracy=0.6340 average_loss=0.8911 The Christian owners of a bakery in Oregon won the lottery shortly after they were fined $135,000 for declining to make a cake for a same-sex wedding.  / 0 ✓
# Test: 71000  71% (67m 0s) average_accuracy=0.5980 average_loss=0.8870 Says Marco Rubio "skipped 18 defense votes including one to arm the Kurds to fight ISIS." Keep the Promise 1 PAC / 1 ✓
# Train: 72000  72% (67m 57s) average_accuracy=0.5790 average_loss=0.9384 Says Congresswoman Loretta Sanchez "has passed one bill in her 20 years in Congress, and that was to rename a post office." Kamala Harris / 1 ✓
# Test: 72000  72% (67m 57s) average_accuracy=0.5960 average_loss=0.9557 After only nine months in office, President Trump and family had already spent $147 million on personal travel, amounting to one-and-a-half times as much as President Obama and family spent in the eight years of the latter's presidency.  / 1 ✓
# Train: 73000  73% (68m 50s) average_accuracy=0.6060 average_loss=0.8997 "I've either balanced every budget or we turned back a surplus." David A. Clarke Jr. / 0 ✓
# Test: 73000  73% (68m 50s) average_accuracy=0.6110 average_loss=0.8971 Says Michelle Nunn has acknowledged allowing a convicted felon to hold a fundraiser for her. Ending Spending Action Fund / 0 ✗ (1)
# Train: 74000  74% (69m 46s) average_accuracy=0.5960 average_loss=1.0052 Says Democratic gubernatorial candidate Mary Burke "has proven on the Madison Board of Education" that she supports raising taxes and spending. Republican Party of Wisconsin / 1 ✓
# Test: 74000  74% (69m 46s) average_accuracy=0.5870 average_loss=0.9703 The Amish don’t get autism because they do not vaccinate their children.  / 0 ✓
# Train: 75000  75% (70m 40s) average_accuracy=0.6240 average_loss=0.8836 Due to the war in Iraq, "4,400 Americans are dead, 30,000 severely wounded and more than 100,000 are suffering from serious health problems related to post traumatic stress syndrome." Ron Paul / 1 ✓
# Test: 75000  75% (70m 40s) average_accuracy=0.5880 average_loss=0.9390 A California teen named Connor Reid Eckhardt was determined to have died after smoking a synthetic marijuana compound known as "spice" or K2.  / 0 ✗ (1)
# Train: 76000  76% (71m 34s) average_accuracy=0.6320 average_loss=0.8898 The Iran deal "trusts the Iranians to inspect themselves." Ted Cruz / 1 ✗ (0)
# Test: 76000  76% (71m 34s) average_accuracy=0.5810 average_loss=0.9855 Says "Hillary Clinton has promised to raise taxes by $1 trillion dollars." New Day for America / 1 ✓
# Train: 77000  77% (72m 30s) average_accuracy=0.5820 average_loss=0.9613 Louie Gohmert of Texas "blamed the mass shooting at a movie theater in Colorado on ‘the ongoing attacks on Judeo-Christian beliefs.'" Gail  Collins / 0 ✗ (1)
# Test: 77000  77% (72m 30s) average_accuracy=0.5430 average_loss=0.9889 "One year ago, (Republicans) would not fill seats vacated for people who went to the administration because of the cost of those elections. Now, they’re talking about changing the rules to add additional elections that will cost millions of dollars of taxpayer expense." Gordon Hintz / 1 ✓
# Train: 78000  78% (73m 27s) average_accuracy=0.5880 average_loss=0.9618  Canada is a "smaller segment" in terms of trade than Mexico.  Donald Trump / 0 ✓
# Test: 78000  78% (73m 27s) average_accuracy=0.5580 average_loss=1.0868  “And what we have done with the remnants of Obamacare is we’ve kept your premiums down far below what anybody would have thought, through good management, through Secretary Alex Azar.”  Donald Trump / 0 ✓
# Train: 79000  79% (74m 20s) average_accuracy=0.5820 average_loss=0.9086 Says Prince invested in Nike in 1971, recruited Michael Jordan to the company in 1983 and designed the first Air Jordans. Facebook posts / 1 ✗ (0)
# Test: 79000  79% (74m 20s) average_accuracy=0.5920 average_loss=0.9207 "No administration has accomplished more in the first 90 days." Donald Trump / 0 ✓
# Train: 80000  80% (75m 16s) average_accuracy=0.6300 average_loss=0.8615 “We spend less than any country in the developed world on children between the ages of zero and 5. It’s just a fact, we don’t invest enough resources.” Ivanka Trump / 0 ✗ (1)
# Test: 80000  80% (75m 16s) average_accuracy=0.5770 average_loss=0.9442 Says Minnesota is "imprisoning half as many people as Wisconsin, and yet our states have virtually identical crime rates." Mike  McCabe / 1 ✓
# Train: 81000  81% (76m 11s) average_accuracy=0.5920 average_loss=0.8778 "The incidents of threats against (President Barack Obama) are greater than for any other president in modern times." Julian Bond / 1 ✗ (0)
# Test: 81000  81% (76m 11s) average_accuracy=0.5980 average_loss=0.9196 "More than half of women under 30 who give birth do so outside of marriage..." Don Beyer / 0 ✗ (2)
# Train: 82000  82% (77m 7s) average_accuracy=0.6020 average_loss=0.9086 California's governor is under investigation for possible corruption.  / 0 ✓
# Test: 82000  82% (77m 7s) average_accuracy=0.5620 average_loss=0.9731  A meme claims Alexandria Ocasio-Cortez said that "owning guns is not a right."  Viral image / 0 ✓
# Train: 83000  83% (78m 2s) average_accuracy=0.6320 average_loss=0.8982 "Sen. McConnell offered a fully paid two-month extension of unemployment insurance." John Cornyn / 1 ✗ (2)
# Test: 83000  83% (78m 2s) average_accuracy=0.6140 average_loss=0.8848 "The Republican presidential nominee hasn’t won women since 1988." Heather McGhee / 1 ✗ (2)
# Train: 84000  84% (78m 57s) average_accuracy=0.5970 average_loss=0.9077 "We really have done a great job. We’re actually taking people that are criminals — very, very, hardened criminals in some cases with a tremendous track record of abuse and problems — and we’re getting them out and that’s what I said I would do." Donald Trump / 1 ✓
# Test: 84000  84% (78m 57s) average_accuracy=0.5800 average_loss=0.8989 "You cannot build a little guy up by tearing a big guy down -- Abraham Lincoln said it." John Kasich / 1 ✗ (0)
# Train: 85000  85% (79m 50s) average_accuracy=0.5970 average_loss=0.9285 Tyson Foods has dropped Labor Day as a holiday in favor of the Muslim celebration of Eid al-Fitr.  / 0 ✓
# Test: 85000  85% (79m 50s) average_accuracy=0.5960 average_loss=0.9867 Floyd Mayweather (or Manny Pacquiao) donated a sizable sum of money to Hurricane Harvey relief efforts.  / 0 ✓
# Train: 86000  86% (80m 44s) average_accuracy=0.5910 average_loss=0.9143 In one year, the United Nations "did 24 resolutions and 20 of them were against Israel." Ron DeSantis / 1 ✗ (0)
# Test: 86000  86% (80m 44s) average_accuracy=0.5870 average_loss=0.9325 Melania Trump plagiarized her statement on Women's History Month from Michelle Obama.  / 0 ✓
# Train: 87000  87% (81m 37s) average_accuracy=0.5850 average_loss=0.9465 "There are some counties in Texas where the first day of hunting, you have to shut down the schools because people are going to go hunting." Lupe Valdez / 1 ✗ (0)
# Test: 87000  87% (81m 37s) average_accuracy=0.6080 average_loss=0.9322 Image depicts "attitude adjustment" and "smile therapy" forced upon American housewives in the 1930s institutionalized for "not taking care of themselves" and acting "depressed."  / 1 ✗ (0)
# Train: 88000  88% (82m 34s) average_accuracy=0.6340 average_loss=0.8694 Says Panasonic stayed in New Jersey because of the Business Retention and Relocation Assistance Grant (BRRAG) program. Kim Guadagno / 0 ✓
# Test: 88000  88% (82m 34s) average_accuracy=0.6100 average_loss=0.8887 U.S. Rep. Patrick Murphy "voted to allow members of Congress to receive taxpayer-funded health care for life." National Republican Senatorial Committee / 1 ✗ (0)
# Train: 89000  89% (83m 27s) average_accuracy=0.6140 average_loss=0.8987 "We created 800,000 new jobs, we cut the unemployment rate almost in half and today New York State has more private sector jobs than it has ever had in its history" Andrew Cuomo / 1 ✗ (2)
# Test: 89000  89% (83m 27s) average_accuracy=0.6130 average_loss=0.8913 Says Sen. Dean Heller "wants to cut programs like Social Security and Medicare to pay for tax cuts for his ultra-wealthy donors." Jacky Rosen / 1 ✓
# Train: 90000  90% (84m 24s) average_accuracy=0.6150 average_loss=0.9270 There are "a larger number of shark attacks in Florida than there are cases of voter fraud." American Civil Liberties Union of Florida / 1 ✓
# Test: 90000  90% (84m 24s) average_accuracy=0.6030 average_loss=0.9346 "Most Americans are now getting their news from Facebook." Rebecca Kleefisch / 0 ✓
# Train: 91000  91% (85m 21s) average_accuracy=0.6020 average_loss=0.8929 "In the entire public school system in Camden last year, only three students graduated college ready." Chris Christie / 1 ✓
# Test: 91000  91% (85m 21s) average_accuracy=0.5890 average_loss=0.9374 Donald Trump was removed from GOP primary ballots in five states.
#
#
#
#
# 						See Example(s)
#
#
#
#
# 									
# Test: 99000  99% (92m 36s) average_accuracy=0.5880 average_loss=0.9005 The Republican-controlled Wisconsin Senate approved a bill "denying veterans the right to recover their medical costs for cancers they developed while serving their country." Chris Larson / 1 ✓
# Train: 100000  100% (93m 29s) average_accuracy=0.6210 average_loss=0.8774 "Twenty-four percent of doctors in Virginia currently don’t accept new Medicaid patients because the reimbursement rates are so low." Dave Schwartz / 1 ✓
# Test: 100000  100% (93m 29s) average_accuracy=0.5950 average_loss=0.9146 "Just like when you ran the State Department, $6 billion was missing. How do you miss $6 billion? You ran the State Department, $6 billion was either stolen. They don't know. It's gone, $6 billion." Donald Trump / 0 ✓

# %%
plt.figure()
plt.plot(all_train_accuracies_2)
plt.plot(all_test_accuracies_2)
plt.title('Q2b (ii) claim and claimant')
plt.ylabel('Accuracy')
plt.xlabel('Epochs (by thousand)')
plt.legend(['Train Accuracy', 'Test Accuracy'], loc='upper left')

# %%
all_train_accuracies_2
# Out:
# [0.442,
#  0.4650000000000001,
#  0.4709999999999999,
#  0.45499999999999996,
#  0.46599999999999986,
#  0.479,
#  0.4810000000000001,
#  0.48300000000000026,
#  0.4590000000000001,
#  0.484,
#  0.5039999999999992,
#  0.48999999999999994,
#  0.452,
#  0.48100000000000004,
#  0.4930000000000001,
#  0.4829999999999999,
#  0.5019999999999999,
#  0.5030000000000001,
#  0.4260000000000001,
#  0.5309999999999998,
#  0.5370000000000007,
#  0.5030000000000018,
#  0.5140000000000006,
#  0.4900000000000001,
#  0.5319999999999994,
#  0.5250000000000002,
#  0.553999999999999,
#  0.5240000000000006,
#  0.5410000000000005,
#  0.5589999999999999,
#  0.5700000000000007,
#  0.5979999999999995,
#  0.5890000000000009,
#  0.6059999999999995,
#  0.6080000000000001,
#  0.5560000000000005,
#  0.5980000000000004,
#  0.5910000000000002,
#  0.5820000000000002,
#  0.6040000000000001,
#  0.5520000000000006,
#  0.5709999999999991,
#  0.5660000000000012,
#  0.5710000000000005,
#  0.5620000000000003,
#  0.5699999999999988,
#  0.574,
#  0.5860000000000014,
#  0.6050000000000004,
#  0.5679999999999991,
#  0.5529999999999999,
#  0.6129999999999999,
#  0.5759999999999998,
#  0.6009999999999998,
#  0.5900000000000006,
#  0.6170000000000002,
#  0.586,
#  0.582,
#  0.6169999999999991,
#  0.5849999999999997,
#  0.6030000000000003,
#  0.5959999999999991,
#  0.5830000000000009,
#  0.5749999999999997,
#  0.5919999999999994,
#  0.6049999999999995,
#  0.5939999999999999,
#  0.5819999999999997,
#  0.6030000000000006,
#  0.5899999999999995,
#  0.6339999999999996,
#  0.579,
#  0.6059999999999989,
#  0.5960000000000009,
#  0.6240000000000001,
#  0.6320000000000005,
#  0.5819999999999984,
#  0.5879999999999999,
#  0.5819999999999991,
#  0.6299999999999992,
#  0.592,
#  0.6020000000000002,
#  0.6319999999999997,
#  0.597,
#  0.5970000000000002,
#  0.5909999999999994,
#  0.5849999999999997,
#  0.6340000000000002,
#  0.6140000000000007,
#  0.6149999999999991,
#  0.6020000000000006,
#  0.5800000000000004,
#  0.6009999999999994,
#  0.6240000000000003,
#  0.589,
#  0.6179999999999988,
#  0.6069999999999993,
#  0.6220000000000002,
#  0.6239999999999996,
#  0.6210000000000001]

# %%
all_test_accuracies_2
# Out:
# [0.4299999999999999,
#  0.44599999999999995,
#  0.477,
#  0.475,
#  0.49500000000000033,
#  0.48,
#  0.4889999999999999,
#  0.486,
#  0.4609999999999999,
#  0.5030000000000003,
#  0.4890000000000002,
#  0.48100000000000004,
#  0.4850000000000007,
#  0.488,
#  0.5100000000000009,
#  0.5059999999999997,
#  0.495,
#  0.5140000000000005,
#  0.48800000000000054,
#  0.5160000000000009,
#  0.5169999999999993,
#  0.542,
#  0.49200000000000105,
#  0.5479999999999994,
#  0.5429999999999989,
#  0.525,
#  0.5329999999999995,
#  0.5300000000000004,
#  0.5420000000000003,
#  0.5629999999999995,
#  0.5719999999999997,
#  0.5879999999999992,
#  0.5679999999999995,
#  0.5730000000000002,
#  0.5740000000000007,
#  0.5720000000000008,
#  0.6010000000000003,
#  0.5809999999999986,
#  0.5869999999999997,
#  0.5709999999999992,
#  0.5530000000000006,
#  0.5739999999999997,
#  0.5759999999999993,
#  0.6010000000000006,
#  0.5639999999999995,
#  0.5720000000000005,
#  0.5999999999999999,
#  0.608,
#  0.5950000000000001,
#  0.574,
#  0.5880000000000001,
#  0.587,
#  0.5750000000000002,
#  0.5689999999999998,
#  0.6070000000000011,
#  0.6109999999999995,
#  0.578,
#  0.599,
#  0.5839999999999995,
#  0.595,
#  0.5719999999999988,
#  0.5699999999999997,
#  0.5549999999999998,
#  0.5569999999999996,
#  0.586,
#  0.5849999999999991,
#  0.606,
#  0.5729999999999991,
#  0.5660000000000007,
#  0.594000000000001,
#  0.5979999999999991,
#  0.5960000000000002,
#  0.6110000000000002,
#  0.5870000000000009,
#  0.5880000000000006,
#  0.5809999999999996,
#  0.5430000000000003,
#  0.5580000000000003,
#  0.5920000000000003,
#  0.5769999999999986,
#  0.5979999999999998,
#  0.5620000000000004,
#  0.6140000000000002,
#  0.5799999999999995,
#  0.5960000000000009,
#  0.5869999999999995,
#  0.6080000000000007,
#  0.6099999999999993,
#  0.6130000000000003,
#  0.6030000000000004,
#  0.5890000000000003,
#  0.5870000000000001,
#  0.5950000000000003,
#  0.5949999999999993,
#  0.5979999999999999,
#  0.6230000000000009,
#  0.5820000000000004,
#  0.6129999999999998,
#  0.5879999999999999,
#  0.5950000000000009]

# %% [markdown]
# ## Preprocessing articles

# %%
def preprocess_articles():

    from nltk.tokenize import sent_tokenize
    import nltk
    nltk.download('punkt')
    from sklearn.feature_extraction.text import TfidfVectorizer
    
    # load metadata
    with open("train.json", 'r') as f:
        metadata = json.load(f)
    n_claims = len(metadata)

    # load related articles for each claim
    relevant_sentences = []
    for id in range(n_claims):
  
        if id % 500 == 0:
            print("Claims preprocessed: ",id)
        
        # retrieve related articles
        related_articles = metadata[id]['related_articles']
        articles = ""
        for article_id in related_articles:
            filename = "train_articles/" + str(article_id) + ".txt"
            # concatenate related articles
            with open(filename, 'r') as text_file:
                text = text_file.read()
                articles = articles + "\n" + text

        # split articles into sentences
        sentences = sent_tokenize(articles)

        # append claim to articles
        sentences.append(metadata[id]['claim'])

        # vectorize sentences based on tf-idf
        vectorizer = TfidfVectorizer()
        X = vectorizer.fit_transform(sentences)
    
        # measure similarity between claim and each sentence
        similarity =  X[-1,:] @ np.transpose(X[:-2,:])
        similarity = similarity.todense()

        # find top 5 sentences with greatest similarity
        sorted_index = np.argsort(similarity)
        top_sentences = []
        for i in range(1,min(5,sorted_index.shape[1])+1):
            top_sentences.append(sentences[sorted_index[0,-i]])
        relevant_sentences.append(top_sentences)

   
    return metadata, relevant_sentences

metadata, relevant_sentences = preprocess_articles()
print("Metadata of claim 0:")
print(metadata[0]['claim'])
print("Relevant sentences of claim 0:")
print(relevant_sentences[0])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Claims preprocessed:  0
# Claims preprocessed:  500
# Claims preprocessed:  1000
# Claims preprocessed:  1500
# Claims preprocessed:  2000
# Claims preprocessed:  2500
# Claims preprocessed:  3000
# Claims preprocessed:  3500
# Claims preprocessed:  4000
# Claims preprocessed:  4500
# Claims preprocessed:  5000
# Claims preprocessed:  5500
# Claims preprocessed:  6000
# Claims preprocessed:  6500
# Claims preprocessed:  7000
# Claims preprocessed:  7500
# Claims preprocessed:  8000
# Claims preprocessed:  8500
# Claims preprocessed:  9000
# Claims preprocessed:  9500
# Claims preprocessed:  10000
# Claims preprocessed:  10500
# Claims preprocessed:  11000
# Claims preprocessed:  11500
# Claims preprocessed:  12000
# Claims preprocessed:  12500
# Claims preprocessed:  13000
# Claims preprocessed:  13500
# Claims preprocessed:  14000
# Claims preprocessed:  14500
# Claims preprocessed:  15000
# Claims preprocessed:  15500
# Metadata of claim 0:
# A line from George Orwell's novel 1984 predicts the power of smartphones.
# Relevant sentences of claim 0:
# ['1984 by George Orwell\n1984 is a dystopian novel by English author George Orwell published in 1949.', 'Theater Review: \'1984\'\nEarly this year, sales of George Orwell\'s novel "1984" spiked after the words "alternative facts" entered the lexicon.', 'It is truly frightening to see the parallels between George Orwell\'s dystopian novel "1984" and the state of our union today.', '\n1984: George Orwell predicted 2017 almost 70 years ago\nApril, 1984.', 'The line is from one of the characters that works for the Government, otherwise known as Big Brother.']

# %%
def sampleClaimClaimantRelevantSentences(metadata): 
    id = random.randint(0, len(metadata) - 1)
    top_related_sentences = " ".join(relevant_sentences[id])
    claim = metadata[id]["claim"] + ' ' + metadata[id]["claimant"] + ' ' + top_related_sentences
    embedding = bpemb_en.embed(claim)
    embedding = np.reshape(embedding,(embedding.shape[0],1,embedding.shape[1]))
    label = metadata[id]["label"]
    label_tensor = torch.tensor([label], dtype=torch.long)
    claim_tensor = torch.tensor(embedding, dtype=torch.float)
    return claim_tensor, label_tensor, claim, label, id

# %%
d_model = 50
heads = 2
N = 6
n_categories = 3
model = Transformer(d_model, N, heads)
classifier = Classifier(d_model, n_categories)

criterion = nn.NLLLoss()
learning_rate = 1e-4

optim = torch.optim.Adam(model.parameters(), lr=learning_rate)
classifierOptimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)

# %%
n_iters = 100000
plot_every = 1000

# Keep track of losses for plotting
current_loss = 0
all_losses = []

start = time.time()

train_data = metadata[:10000]
test_data = metadata[10000:]

train_cumulative_loss = 0
test_cumulative_loss = 0
average_train_accuracy = 0
average_test_accuracy = 0

all_train_losses_3 = []
all_train_accuracies_3 = []
all_test_losses_3 = []
all_test_accuracies_3 = []

count = 0
for iter in range(1, n_iters + 1):
    train_line_tensor, train_category_tensor, train_line, train_category, train_id = sampleClaimClaimantRelevantSentences(train_data)
    train_output, train_loss = train(train_category_tensor, train_line_tensor)    
    top_train_value, top_train_index = train_output.topk(1)
    train_guess_category = top_train_index[0].item()
    train_cumulative_loss += train_loss
    train_accuracy = 1 if train_guess_category == train_category else 0
    average_train_accuracy = (average_train_accuracy * count + train_accuracy) / (count+1)
    
    test_line_tensor, test_category_tensor, test_line, test_category, test_id = sampleClaimClaimantRelevantSentences(test_data)
    test_output, test_loss = train(test_category_tensor, test_line_tensor, update=False)
    top_test_value, top_test_index = test_output.topk(1)
    test_guess_category = top_test_index[0].item()
    test_cumulative_loss += test_loss
    test_accuracy = 1 if test_guess_category == test_category else 0
    average_test_accuracy = (average_test_accuracy * count + test_accuracy) / (count+1)
    count += 1

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        train_correct = '✓' if train_guess_category == train_category else '✗ (%s)' % train_category
        print('Train: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_train_accuracy, train_cumulative_loss / plot_every, train_line, train_guess_category, train_correct))
        test_correct = '✓' if test_guess_category == test_category else '✗ (%s)' % test_category
        print('Test: %d  %d%% (%s) average_accuracy=%.4f average_loss=%.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), average_test_accuracy, test_cumulative_loss / plot_every, test_line, test_guess_category, test_correct))
        
        all_train_losses_3.append(train_cumulative_loss / plot_every)
        all_train_accuracies_3.append(average_train_accuracy)
        all_test_losses_3.append(test_cumulative_loss / plot_every)
        all_test_accuracies_3.append(average_test_accuracy)
        
        train_cumulative_loss = 0
        average_train_accuracy = 0
        test_cumulative_loss = 0
        average_test_accuracy = 0
        count = 0
# Out:
# Train: 1000  1% (3m 50s) average_accuracy=0.4680 average_loss=14.7067 "African Americans in Missouri are 75 percent more likely to be stopped and searched by law enforcement officers than caucasians." Derrick  Johnson The advisory was drafted in response to race-based incidents, according to Mr. Shelton, including death threats against black students at the University of Missouri campus in November 2015 and the discovery of the statistics from the Missouri Attorney General’s Office saying that African Americans in Missouri are 75 percent more likely to be stopped and searched by police than Caucasians. has reviewed and decided to retain its recent advisory urging African-Americans to steer clear of Missouri in the wake of the finding that African-Americans are 75 percent more likely to be stopped by the police than whites and after a new state law that the organization said makes it harder to sue businesses for racial discrimination. African-Americans were 1.57 times more likely to be searched than whites (8.77/5.57). African-Americans and Hispanics are searched more often than whites, but they are arrested more often as well. The NAACP’s advisory also cites the most recent attorney general’s report showing black drivers in Missouri were 75 percent more likely to be pulled over than whites. / 0 ✗ (1)
# Train: 11000  11% (32m 43s) average_accuracy=0.4960 average_loss=1.6105 Mitch McConnell "ordered the Republican Judiciary Committee Chairman to do away with the long-standing requirement that senators be consulted about circuit court judicial nominees in their home states." Charles Schumer Feinstein, the top Democrat on the Senate Judiciary Committee, says Republicans are torching a century-old custom that allows individual senators to block judicial nominees from their home states. There’s less reason to defer to the views of a single state’s senator for such nominees.”
#
# The Pinocchio Test
#
# Feinstein says Republicans are doing away with a 100-year-old tradition of allowing senators to block judicial nominees from their home states. From 1917 to 1955, the blue slip was used as a feedback tool “to merely request the opinion of senators, regardless of political party, about judicial nominations in their home-states,” according to the CRS report. Once the president submits a judicial nomination to the Senate, the chairman of the Senate Judiciary Committee sends a blue-colored form (or “blue slip”) to both senators from the nominee’s home state. “It gives senators the opportunity to have a say on nominees from their states. / 1 ✓
# Test: 11000  11% (32m 43s) average_accuracy=0.4330 average_loss=1.9482 Says you can buy four light bulbs for $1.99 at Walmart, while a single compact fluorescent lamp (CFL) costs "$10 a pop." Joe Barton 2393, Country of Origin Labeling Amendments Act of 2015
# H.R. 2015—Subsec. In 2015, USDA received an appropriation of $5 million for country-of-origin inspections. 0345.15
#
# Contact:
#
# USDA Office of Communications 202-720-4623
#
#
#
# Printable version
#
# Email this page
#
# Statement from Agriculture Secretary Tom Vilsack on the Country of Origin Labeling Requirements for Beef and Pork
#
# WASHINGTON, Dec. 18, 2015 – Agriculture Secretary Tom Vilsack today released the following statement regarding the language in the omnibus bill repealing the country of origin labeling requirements for beef and pork products. "The omnibus bill repealed the country of origin labeling (COOL) requirements for muscle cuts of beef and pork, and ground beef and pork. / 1 ✓
# Train: 12000  12% (35m 35s) average_accuracy=0.5080 average_loss=1.8019 Satellite images of hexagon-shaped holes in clouds above the Bermuda Triangle prove that large blasts of sinking air are the cause of mysterious shipwrecks and plane crashes in the area.  “They are formed by what are called microbursts and they’re blasts of air that come down out of the bottom of a cloud and then hit the ocean and then create waves that can sometimes be massive in size as they start to interact with each other.”
#
# The Bermuda Triangle is roughly mapped out to the east of The Bahamas and the west of Bermuda Island in the North Atlantic Ocean. Satellite weather images showing honeycomb cloud patterns, like those above the Bermuda Triangle, are strange to see, but not uncommon. Could mysterious hexagonal clouds in Bermuda Triangle caused by 170mph 'air bombs' be behind centuries of bizarre disappearances? Hexagonal clouds creating terrifying air bombs with winds of 170mph could be behind the mystery of the Bermuda Triangle
#
# The mystifying 500,000km square patch in the North Atlantic Ocean has been blamed for the disappearance of at least 75 planes and hundreds of ships, but the oddly-shaped clouds may hold the secret to the vanishing acts
#
# The winds created by the so-called air bombs are so powerful they generate 45ft high winds
#
# The winds created by the so-called air bombs are so powerful they generate 45ft high winds. Hexagonal clouds creating terrifying air bombs with winds of 170mph could be behind the mystery of the Bermuda Triangle. / 0 ✓
# Test: 12000  12% (35m 35s) average_accuracy=0.4330 average_loss=2.0573 Malia Obama was "among 10 arrested in racist Antifa attack," and the cop who arrested her was "found dead under suspicious circumstances." Bloggers That revelation is in an email that disgraced FBI counterintelligence agent Peter Strzok wrote to FBI executives around the time BuzzFeed published a version of the dossier on Jan. 10, 2017. employees, Lisa Page and Peter Strzok, texted about investigating possible collusion between Trump and the Russians. Fusion GPS has attracted scrutiny because Republican lawmakers have spent the better part of this year investigating whether the dossier, which was funded by the Hillary Clinton campaign and the Democratic National Committee, served as the basis for the Justice Department and the FBI to obtain FISA surveillance last year on a Trump campaign adviser named Carter Page. The first time Steele met the FBI on July 5, 2016, he got a lukewarm reception. Together, the Fusion connections for Mr. and Mrs. Ohr have raised Republican concerns about objectivity at the Justice Department, and even spurred a call from Trump’s outside counsel for a separate special prosecutor. / 2 ✗ (0)
# Train: 13000  13% (38m 24s) average_accuracy=0.4950 average_loss=1.5418 Says Emma Gonzalez, a survivor of the Parkland school shooting, ripped up a copy of the U.S. Constitution Viral image Read more:
#
# Rep. Steve King’s campaign ties Parkland’s Emma González to ‘communist’ Cuba
#
# Why Paul McCartney marched: ‘One of my best friends was killed in gun violence’
#
# 300 students share their thoughts on how to make schools safe
#
# Meet the young protesters opposing gun violence, face to face
# No, Emma González did not rip up the U.S. Constitution
# Emma González's arresting speech at the March for Our Lives is one we won't forget for years to come. The mass walkouts held around the country on March 14, which marked the one-month anniversary of the mass shooting at our school, weren’t even organized by March for Our Lives. — LR (@Gunslinger2929) March 24, 2018
#
# "Nothing says 'I am NOT a fascist' like tearing up the greatest symbol of freedom that the world has ever known," replied one Twitter user. To depict the destruction of the Constitution is the most in-American act that one can display, it surpassed the burning of the flag and dishonors every person who has served to protect this country.
# A fake photo of Emma González went viral on the far right, where Parkland teens are villains
# Having teenagers act as figureheads for a movement has a certain quality that has not gone unnoticed in the wake of the March for Our Lives rally on Saturday. / 0 ✓
# Test: 13000  13% (38m 24s) average_accuracy=0.4330 average_loss=1.7812 The Keystone XL pipeline "doesn’t even have any oil for America." Kirsten Gillibrand (h)(4)(E) to (G). (B) to (D). (E) to (G). (q) as (r), without specifying the act to be amended, was executed by making the amendments to this section, which is section 501 of the Internal Revenue Code of 1986, to reflect the probable intent of Congress. L. 99–514, § 1899A(15), substituted “ ” for “the date of the enactment of the Tax Reform Act of 1984”. / 2 ✗ (1)
# Train: 14000  14% (41m 18s) average_accuracy=0.4870 average_loss=1.6857 Says Romney wants to add $2 trillion to the defense budget that the military hasn’t asked for. Barack Obama
# Defense spending to spike $2.1 trillion under Romney
# Mitt Romney wants to spend more on ships, planes and troops. Compared to the Pentagon's current budget, Romney's plan would lead to $2.1 trillion in additional spending over the next ten years, according to an analysis conducted for CNNMoney by Travis Sharp, a budget expert at the Center for a New American Security. Asked if the military needs to spend 4% of GDP, Lawrence Korb, a senior fellow at the Center for American Progress who advocates for lower military spending, said "of course not." The additional funding would provide funds to bolster the fleets, Romney says. The former Massachusetts governor wants to increase defense spending by leaps and bounds. / 1 ✗ (2)
# Test: 14000  14% (41m 18s) average_accuracy=0.4510 average_loss=2.0344 Says President Donald Trump as a candidate mentioned WikiLeaks "over 160 times in speeches" in the last month of the campaign. Jackie Speier In 2018, provisional estimates show the economy grew by 6.1%. – Vincent Ng’ethe
#
# Economy
#
# Claim “Our real Gross Domestic Product (GDP) grew by 4.9 percent in 2017.” Verdict correct
#
# Train: 17000  17% (49m 56s) average_accuracy=0.4900 average_loss=1.4776 A lunar eclipse occurring on 27 July 2018 will be the longest duration total lunar eclipse of the 21st century.  The full moon on the night of July 27-28, 2018, presents the longest total lunar eclipse of the 21st century (2001 to 2100). Bottom line: July 27, 2018, brings the longest total eclipse of the moon of the 21st century. Even so, this July 2018 total lunar eclipse counts as a whopper, giving us the longest total lunar eclipse of the 21st century. On July 27, 2018, the center of the lunar disk will swing a tiny bit north of the shadow’s center, so this total lunar eclipse with a duration of 1 hour and 43 minutes will be a few minutes shy of the maximum duration possible (1 hour and 47 minutes). Longest Penumbral Lunar Eclipse: 1322 Nov 24 Duration = 296.5m Longest Partial Lunar Eclipse: 2669 Feb 08 Duration = 210.0m Longest Total Lunar Eclipse: 0318 May 31 Duration = 106.6m
#
# Five Millennium Catalog of Lunar Eclipses: -1999 to +3000 (2000 BCE to 3000 CE)
#
# The table below summarizes the statistical distribution of lunar eclipse types over this five millennium period. / 0 ✗ (2)
# Test: 17000  17% (49m 56s) average_accuracy=0.4240 average_loss=1.6174 Says Tallahassee mayor Andrew Gillum "wants to make Florida not a sanctuary city but a sanctuary state." Adam Putnam Harry S. Truman Presidential Museum & Library
# Did Truman pardon a Turkey? The Truman Library has received many requests over the years for information confirming the story that President Truman "pardoned" a Thanksgiving turkey in 1947, thus initiating a Presidential tradition that continues to this day. Various groups presented turkeys to President Truman, often during the Christmas season instead of at Thanksgiving. In any event, the Library has been unable to determine when the tradition of pardoning the turkey actually began. The Library's staff has found no documents, speeches, newspaper clippings, photographs, or other contemporary records in our holdings which refer to Truman pardoning a turkey that he received as a gift in 1947, or at any other time during his Presidency. / 0 ✗ (1)
# Train: 18000  18% (53m 24s) average_accuracy=0.4900 average_loss=2.2803 In Ohio, due to Medicaid expansion, "nearly 60,000 disabled citizens are stuck on waiting lists ... leaving them without the care they need for months or even years." Mike Pence I know Governor Kasich isn’t with us, but I suspect that he’s very troubled to know that in Ohio alone, nearly 60,000 disabled citizens are stuck on waiting lists, leaving them without the care they need for months or even years. (John) Kasich isn’t with us, but I suspect that he’s very troubled to know that in Ohio alone, nearly 60,000 disabled citizens are stuck on waiting lists, leaving them without the care they need for months or even years,” Pence asserted at the National Governors Association gathering Friday in Providence, Rhode Island. Nearly 60,000 disabled Ohioans are on waiting lists that last for months or years to receive supplemental state services. The editorial said, “Nearly 60,000 disabled Ohioans are on waiting lists that last for months or years to receive supplemental state services.”
#
# Those Ohioans, however, are on a list seeking Medicaid waivers, mostly for home- and community-based services for the developmentally disabled. VP Pence spreading 'fake news' about Ohio
# About a week after the White House spread misinformation about Ohio’s Medicaid program, Vice President Mike Pence falsely said Friday that 60,000 Ohioans are going without care because of the state’s Medicaid expansion. / 0 ✓
# Test: 18000  18% (53m 24s) average_accuracy=0.4310 average_loss=2.0426 "Miss Universe Guyana 2017 arrested at London Heathrow airport with 2 kilograms of cocaine." states-news.com And with the developments in Libya, for example, the Libyan people have voted twice in free and fair elections for the kind of leadership they want. And with the developments in Libya, for example, the Libyan people have voted twice in free and fair elections for the kind of leadership they want. That’s the power of free people. That's the power of free people. I have voted for them and I have voted against them when I was a senator. / 0 ✓
# Train: 19000  19% (56m 15s) average_accuracy=0.4970 average_loss=1.2516 "A recent study revealed that, across the nation, taxes would have to be increased by an average of $1,300 a year just to support the currently unsustainable public employee pension systems. In Florida, that dollar figure translates to $813 a year." Rick Scott Though checks will still be in the mail for Florida's public retirees, by July the fund is expected to have just 87 cents for every dollar in pension promises made. $15.4 billion Florida's public pension fund deficit in fiscal year 2009, compared with a surplus
#
# of $8.2 billion at the end of the previous year. One of Scott's vetoes targeted a measure that would have allowed counties to create organizations to solicit private donations to pay for additional guardian ad litem support. And the fund's shortfall is projected to be even bigger this year. It's the first pension reform proposal to get a hearing this year. / 1 ✓
# Test: 19000  19% (56m 15s) average_accuracy=0.4330 average_loss=1.4364 Says she will "work to raise the federal minimum wage back to the highest level it’s ever been — $12 an hour in today’s dollars." Hillary Clinton 55
#
# Proposing an amendment to the Constitution of the United States relating to the equal application to the Senators and Representatives of the laws that apply to all citizens of the United States. Warren Buffett's 5-Minute Plan to Fix the Deficit
# Billionaire Warren Buffett believes he has the solution for solving America's deficit crisis, and it involves forcing politicians to actually do their job. Resolved by the Senate and House of Representatives of the United States of America in Congress assembled (two-thirds of each House concurring therein), That the following article is proposed as an amendment to the Constitution of the United States, which shall be valid to all intents and purposes as part of the Constitution when ratified by the legislatures of three-fourths of the several States within seven years after the date of its submission for ratification:
#
# `Article--
#
# `Congress shall make no law respecting the citizens of the United States that does not also apply to the Senators and Representatives.'. Congress must equally abide by all laws they impose on the American people. Section 2 - State citizens, Extradition
#
# The Citizens of each State shall be entitled to all Privileges and Immunities of Citizens in the several States. / 2 ✗ (1)
# Train: 20000  20% (59m 6s) average_accuracy=0.4920 average_loss=1.3979 "One of the things I would immediately do … is bring back the warrior class -- Petraeus, McChrystal, Mattis, Keane, Flynn. ... Every one was retired early because they told President Obama things that he didn’t want to hear." Carly Fiorina Every one was retired early because they told President Obama things that he didn't want to hear. One of the things I would immediately do, in addition to defeating them here at home, is bring back the warrior class -- Petraeus, McChrystal, Mattis, Keane, Flynn. One of the things my grandfather instilled in me, was that I was really blessed because I was a citizen of the greatest country in the history of our mankind. One of the things that you'll notice if you look through my life is that I don't do a lot of talking. He made things worse. / 0 ✗ (1)
# Test: 20000  20% (59m 6s) average_accuracy=0.4590 average_loss=1.4297 Prolonged sexual arousal in men without an ejaculation can cause pain, a condition colloquially referred to as "blue balls".  They haven’t gone up for a long time. (APPLAUSE)
#
# They haven’t gone up for a long time. It’s gone. This has been going on for a long, long time. It's been going on for a long time in our country. / 0 ✗ (2)
# Train: 21000  21% (62m 0s) average_accuracy=0.4580 average_loss=1.3847 An Ohio Walmart store has begun selling halal meat.
# Walmart to sell halal meat option
# Staff Writer
#
# Upon the request of Muslim students at Miami University, Walmart recently made the decision to provide halal-certified meat at the
#
#
# What follows is the article that likely pushed Steve Bannon, President Trump’s chief strategist and architect of his white nationalist messaging, out the White House door. This is also puzzling, since Steve Bannon is not exactly Bambi when it comes to dealing with the press. “To me,” Bannon said, “the economic war with China is everything. You might think from recent press accounts that Steve Bannon is on the ropes and therefore behaving prudently. If the left is focused on race and identity, and we go with economic nationalism, we can crush the Democrats.”
#
# I had never before spoken with Bannon. / 0 ✓
# Test: 43000  43% (124m 56s) average_accuracy=0.4430 average_loss=1.2334 The United States "is the only major country that taxes its own exports." Kevin Brady According to SNHR, Russia’s death toll comprises largely of hits on contested cities such as Deir ez-Zor, Aleppo, Idlib and Raqqa, while the biggest target for the Syrian military’s advances have been the suburbs of Damascus. The Security Council has been deeply divided over the Syrian conflict, which began in March 2011 with protests calling for political change but has evolved into a full-scale civil war. Pillay said "the lack of consensus on Syria and the resulting inaction has been disastrous, and civilians on all sides have paid the price." This was just the latest consignment of arms and ammunition sent by Russia in support of the Assad government, a close ally with whom Moscow has maintained good relations for decades. If there is a realisation within the regime that it is falling, that it has lost the confidence of its own allies internationally… influential members will try to defect Malik al-Abdeh, Syrian journalist
#
# The country is perilously close to civil war as the ranks of a rebel army swell with defecting soldiers and as government forces step up their assaults on towns and cities now that the Arab League monitoring mission has ended in failure. / 0 ✗ (1)
# Train: 44000  44% (127m 46s) average_accuracy=0.5130 average_loss=1.0954 A photograph shows a wooden box covering a statue of George Washington at an NAACP event.  The S.C. NAACP said Tuesday it was not trying to hide a State House statue of George Washington at its annual Martin Luther King Jr. Day rally Monday. Photos from the event showed a three-sided box with Washingtons statue visible only from behind the stage. A three-sided structure that covered the front and sides of the statue was intended to display a rally graphic and serve as a photo-and-television backdrop for the events speakers, said S.C. NAACP executive director Dwight James. The group has draped the founding fathers statue at previous rallies. Not so, says the NAACP. / 0 ✗ (1)
# Test: 44000  44% (127m 46s) average_accuracy=0.4510 average_loss=1.1595 Says Chris Koster "fell silent" as attorney general in pursuing a case against a free classified service accused of promoting prostitution after accepting "over $12,000 in campaign contributions' from people affiliated with the service." Eric  Greitens Sorry, Republican Rauner should not be the standard of good government for Democrats, even for the rich ones. Let’s hold this field of progressives to a standard that Paul Simon would be proud of. But for years it had been standard practice for most candidates in major statewide races to release their complete returns. In short, they need to have trust in their elected officials — something that is in short supply today. Rauner has now released five years of tax return cover sheets since announcing his candidacy for governor in late 2013. / 0 ✗ (1)
# Train: 45000  45% (130m 42s) average_accuracy=0.5220 average_loss=1.2012 Did Charles Krauthammer Write an Op-Ed Arguing for 'Trump the Pragmatist'?  Contact: charleskrauthammer.com
# FACT CHECK: Did Charles Krauthammer Write an 'Interesting Take on Trump?' In February 2018, an op-ed ostensibly written by Krauthammer which argued that Trump was neither a Republican or a Democrat, but a pragmatist, started getting passed around via e-mail and social media.
# A different take on Trump the pragmatist
# ▲
#
# Editor’s note: Charles Krauthammer is back on a partial basis after taken time off for surgery. Charles Krauthammer is a well-known, venerable political commentator who has been around — and respected — for decades, which is probably why his byline is occasionally affixed to articles he did not author. * Charles Krauthammer’s column is distributed by The Washington Post Writers Group. / 0 ✓
# Test: 45000  45% (130m 42s) average_accuracy=0.4570 average_loss=1.2938 In July 2016, Massachusetts implemented a new ban on the sale of all semi-automatic rifles.  (The year-to-year difference has varied in 2015, ranging from nothing in January to 83 percent in August to 129 percent in May). …
#
# Justin
#
# From: Jankowski, Philip (CMG-Austin)
#
# Sent: Monday, October 12, 2015 4:30 PM
#
# To: Newsom, Justin
#
# Subject: Politifact check on murders
#
# ... We’re working on making our count of homicides from January through August 2014 match with the APD count from the chief’s monthly report from August 2014. - 12
# 1015 ehlertapd
#
# Email, Lt. Scott Ehlert, Austin Police Department, Oct. 13, 2015
#
# From: Selby, Gardner (CMG-Austin)
#
# Sent: Monday, October 12, 2015 2:02 PM
#
# To: Newsom, Justin
#
# Subject: Following up
#
# Can you be specific about the six officer-involved fatal shootings in 2015? The attached graphic is a good visual that shows a consistent murder rate over multiple years. g.
#
# From: Newsom, Justin
#
# Sent: Tuesday, October 13, 2015 10:30 AM
#
# To: 'Selby, Gardner (CMG-Austin)'; Ehlert, Scott
#
# Subject: RE: Following up
#
# I will defer to Lt. Scott Ehlert in SIU to answer the questions related to officer involved shootings. / 0 ✗ (1)
# Train: 46000  46% (133m 38s) average_accuracy=0.5200 average_loss=1.2115 The medicine works. The bhang will ensure that all the body agents that cause measles are killed. Women in Kenyan city of Kisumu The bhang will ensure that all the body agents that causes measles are killed. “The medicine works. It doesn’t cause a high. Measles outbreaks can result in epidemics that cause many deaths, especially among young, malnourished children. WHO will continue to strengthen the global laboratory network to ensure timely diagnosis of measles and track international spread of the measles viruses to allow more coordinated approach in targeting vaccination activities and reduce measles deaths from this vaccine-preventable disease. / 1 ✗ (0)
# Test: 46000  46% (133m 38s) average_accuracy=0.4700 average_loss=1.2824 Says "80 percent of the tax breaks in" President Donald Trump’s tax-cut "proposal go to the top 1 percent, that is, people making more than $730,000 a year." Lloyd  Doggett You can't cut it, regardless of the budget circumstances, regardless. You can't cut it, regardless of the budget circumstances, regardless. You can't cut it. You can't cut it. And this health care bill is going to be mandated spending. / 1 ✓
# Train: 47000  47% (136m 29s) average_accuracy=0.5070 average_loss=1.1012 Mitt Romney’s son Tagg owns a company that manufactures voting machines.  Is Mitt Romney’s son going to hijack Ohio’s vote count? In recent weeks, Columbus-based FreePress.org—where I wrote many articles after 2004 examining what happened in that election—has been reporting that Mitt Romney’s son Tagg is an owner in a voting machinery company whose equipment will be used to scan and count paper ballots in Hamilton County , where Cincinnati is located, and another small rural county up north. The implication is that the company’s employees will pre-program high-speed scanners to register more votes for Romney than Obama. It is not the first time that a voting machine company owner has sided with a Republican presidential candidate in Ohio. It's true that there’s no recount possible with most of the voting machines in these two states (you can look up what voting technology is used in your state here ), which is not good. / 0 ✓
#
# Canada fell a victim in January 2016, after it implemented sanctions against Russia. Germans in the east may also remember the poor state of the Soviet army leaving Germany and thus may not believe that same army could pose a real threat. / 0 ✗ (1)
# Test: 49000  49% (142m 4s) average_accuracy=0.4720 average_loss=1.1405 "Recently we have seen our government debt grow by $3.4 trillion during the first 29 months of the Obama administration -- the equivalent of about $4 billion per day." Leonard Lance
# Trump: If soldiers were 'real patriots,' they wouldn't take a pay raise
# The draft dodger in chief had the audacity to 'joke' about the patriotism of our military. Trump: If soldiers were 'real patriots,' they wouldn't take a pay raise
# The draft dodger in chief had the audacity to 'joke' about the patriotism of our military. Are these real patriots? Are these real patriots? Are these real patriots? / 0 ✗ (1)
# Train: 50000  50% (144m 55s) average_accuracy=0.5210 average_loss=1.0380 A WhatsApp video known as "Martinelli" spreads malware that irreparably hacks your cell phone.  Fuente: El Grupo Informático
# FACT CHECK: 'Popcorn Carnival' WhatsApp Hoax
# In July 2017, WhatsApp users began spotting a message claiming that a “video filming” known as “Popcorn Carnival” (or “Carnaval de las palomitas”) was “hacking” phones:
#
# There is a video filming going around on Whatsapp called “Popcorn Carnival”. Please forward to your contacts as soon as possible. The rumor is that “Carnaval de las palomitas” is going around in Whatsapp and will hack your phone instantly! Versions of the warning circulated on Facebook as well as WhatsApp, but nothing that we found included any explanation about what sort of risk the “hacking” of phones might pose. It will Hack your phone in seconds and you cannot stop it in anyway. / 0 ✓
# Test: 50000  50% (144m 55s) average_accuracy=0.4750 average_loss=1.0893 Says North Carolina's replacement for HB2 "orders NC cities to discriminate against LGBT people until at least 2020 and unfair ‘bathroom bans’ remain." Caitlyn Jenner The administration said the new nonprofit health insurers will be run by their customers, and will be designed to offer coverage to individuals and small businesses. He said the outcome should not have been a surprise. CoOportunity Health is an insurance cooperative, which was set up to give consumers and small businesses an alternative in a market with few choices. If you do not purchase replacement insurance, you may be penalized by the federal government. You have until Feb. 15 to enroll in another plan. / 0 ✓

# %%
plt.figure()
plt.plot(all_train_accuracies_3)
plt.plot(all_test_accuracies_3)
plt.title('Q2b (iii) claim, claimant and relevant sentences')
plt.ylabel('Accuracy')
plt.xlabel('Epochs (by thousand)')
plt.legend(['Train Accuracy', 'Test Accuracy'], loc='upper left')

# %%
all_train_accuracies_3

# %%
all_test_accuracies_3

# %% [markdown]
# # Plots

# %%
plt.figure()
plt.plot(all_train_accuracies)
plt.plot(all_train_accuracies_2)
plt.plot(all_train_accuracies_3)
plt.title('Q2b Train Accuracy')
plt.ylabel('Train accuracy')
plt.xlabel('Epochs (by thousand)')
plt.legend(['i) claim', 'ii) claim and claimant', 'iii) claim and claimand and relevant sentences'], loc='upper left')
plt.show()

# %%
plt.figure()
plt.plot(all_test_accuracies)
plt.plot(all_test_accuracies_2)
plt.plot(all_test_accuracies_3)
plt.title('Q2b Test Accuracy')
plt.ylabel('Test accuracy')
plt.xlabel('Epochs (by thousand)')
plt.legend(['i) claim', 'ii) claim and claimant', 'iii) claim and claimand and relevant sentences'], loc='upper left')
plt.show()
